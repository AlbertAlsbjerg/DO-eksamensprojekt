# %% [markdown]
# # DO2021: Eksamensprojekt kode
# *Af Anders Reinholdt Sindberg & Albert Neve Alsbjerg*

# %% [markdown]
# ## Indholdsfortegnelse
# 1. Indledning
# 2. Web Scraping: Hent og behandling af punktligheds-data fra DSB's hjemmeside
# 3. Web Scraping: Hent og behandling af punktligheds-data fra Banedanmarks hjemmeside
# 4. Behandling af togpunktlighedsdata på Københavns Hovedbanegård

# %% [markdown]
# ## Indledning
# **`Note: Dette er bare udkast til indledning. Når vi har overblikket kan vi skrive det ordenligt (og tilføje til listen over data vi bruger) `**
#
# Både DSB og Banedanmark har et mål om at forbedre punktligheden. Dertil foreslår Banedanmark en “forenkling” af Københavns Hovedbanegård, der indebære en ombygning af togsporene.
#
# Hvorfor er det først efter 23 år med store problemer med punktligheden og store udgifter på KBH, at banedanmark foreslår en løsningsplan på?
#
# Denne notebook vil gennemgå kode og dataanalyse nødvendig til at belyse ovenstående. Det kræver følgende data:
# * Historisk data over togpunktlighed på Hovedbanegården
# * Nuværende omkostninger
# * Simuleringsdata over gevinster ved forenkling af Hovedbanegården

# %% [markdown]
# ### Klargøring
# Til behandling af vores data vil vi bruge følgende biblioteker:
# - **pandas** til [...]
# - **numpy** til matematiske funktioner
# - **requests** til at forbinde til en webside
# - **beautifulsoup** og **regex** til parsing af data fra web scraping.
# - **matplotlib** til at plotte og illustrere data
# - **time** til at formindske fejl i koden

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import time

# %% [markdown]
# ## Togpunktlighed: Web scraping fra DSB
# Historisk data over togpunktlighed og kompensationsgrad hentes fra DSB's hjemmeside.
#
# Ved at inspicere hjemmesiden kan det ses, at data'en er opdelt i måned og år. Yderligere er data'en opdelt efter strækning, hvor der på hver strækning findes data for mål for kundepunktligheden, den faktiske punktlighed og kompensationen i procent.
#
# Dette data vil blive hentet og gemt i et dataframe.

# %% [markdown]
# ### Den relevante data lokeres i html fra hjemmesiden
# Ved brug af `requests`og `beautifulsoup` vil hjemmesidens html data blive hentet og parset, hvorefter den relevante data vil blive gemt i et `pandas` dataframe.
#
# Først hentes html fra den relevante side hos DSB og gemmes med `beautifulsoup`. Derefter printes html, så hjemmesidens opbygning kan aflæses og den relevante data kan lokeres:

# %%
# URL til data'en på DSB's hjemmeside indlæses, hentes, og gemmes som beautifulsoup objekt:
url = "https://www.dsb.dk/find-produkter-og-services/dsb-rejsetidsgaranti/dsb-pendler-rejsetidsgaranti/kompensationsstorrelse/trafikdata-for-fr---ny/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

#html data printes og inspiceres
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 8 ]>				<html class="ie lt-ie8 lt-ie9 lt-ie10 no-js" lang="da"> <![endif]-->
# <!--[if IE 8 ]>					<html class="ie ie8 lt-ie9 lt-ie10 no-js" lang="da"> <![endif]-->
# <!--[if IE 9 ]>					<html class="ie ie9 lt-ie10 no-js" lang="da"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" lang="da">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>
#         DSB | Trafikdata for Fjern- og regionaltog - kundepunktlighed
#     </title>
# <meta content="Her finder du trafikdata for kundepunktligheden på din strækning opgjort på månedsbasis. Se din kompensationsgrad her." id="PageDescriptionID" name="description"/>
# <script id="dsb-cached-fonts" type="text/javascript">
#         !function(a){"use strict";function c(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function d(a){return window.localStorage&&localStorage.font_css_cache&&localStorage.font_css_cache_file===a}function e(){if(window.localStorage&&window.localStorage.length&&window.XMLHttpRequest)if(d(b))f(localStorage.font_css_cache);else{var c=new XMLHttpRequest;c.open("GET",b,!0),c.onreadystatechange=function(){4===c.readyState&&200===c.status&&(f(c.responseText),localStorage.font_css_cache=c.responseText,localStorage.font_css_cache_file=b)},c.send()}else{var a=document.createElement("link");a.href=b,a.rel="stylesheet",a.type="text/css",document.getElementsByTagName("head")[0].appendChild(a),document.cookie="font_css_cache"}}function f(a){var b=document.createElement("style");b.setAttribute("type","text/css"),document.getElementsByTagName("head")[0].appendChild(b),b.styleSheet?b.styleSheet.cssText=a:b.innerHTML=a}var b=a;window.localStorage&&localStorage.font_css_cache||document.cookie.indexOf("font_css_cache")>-1?e():c(window,"load",e)}("/html/dist/css/fonts.css?v=b6.0.647.7");
#     </script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.5.1/jquery.min.js"></script>
# <script src="/Scripts/jquery.validate.js"></script>
# <script src="/Scripts/jquery.validate.unobtrusive.min.js"></script>
# <script src="/Scripts/jquery.unobtrusive-ajax.min.js"></script>
# <script src="/Scripts/modernizr.js"></script>
# <script src="/Scripts/svg4everybody.min.js"></script>
# <script src="/html/dist/js/gtmBundle.js?version=b6.0.647.7"></script>
# <link href="//customer.cludo.com/assets/2014/9676/cludo-search.min.css" rel="stylesheet" type="text/css"/>
# <link href="/html/dist/css/styles.css?v=b6.0.647.7" rel="stylesheet"/>
# <!--[if lt IE 9]>
#         <link href="~/html/dist/css/ie8.css" rel="stylesheet">
#     <![endif]-->
# <!-- For IE 8 and earlier -->
# <!--[if lt IE 9]>
#         <script type="text/javascript" src="/html/dist/js/nddk-requirejs/modules/libs/respond.js"></script>
#     <![endif]-->
# <!--[if lt IE 10]>
#         <script type="text/javascript" src="/Scripts/media.match.js"></script>
#     <![endif]-->
# <!-- For IE 8 and earlier -->
# <!--[if lt IE 9]>
#         <script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.6.2/html5shiv.js"></script>
#         <script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/json3/3.2.5/json3.min.js"></script>
#         <script type="text/javascript" src="//cdnjs.cloudflare.com/ajax/libs/selectivizr/1.0.2/selectivizr-min.js"></script>
#     <![endif]-->
# <script>
#         window.securityTokenRefresh = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJodHRwOi8vc2NoZW1hcy5taWNyb3NvZnQuY29tL3dzLzIwMDgvMDYvaWRlbnRpdHkvY2xhaW1zL2V4cGlyYXRpb24iOiJyZWZyZXNoIiwibmJmIjoxNjM5NzQ0MDMzLCJleHAiOjE2Mzk3NDU4MzMsImlhdCI6MTYzOTc0NDAzM30.Ua_56Lt5YSZOx2HbM6QEIvs7kH1xrL13TAFSdM3jUvQ';
#     </script>
# <link href="/html/dist/css/print.css?v=b6.0.647.7" media="print" rel="stylesheet"/>
# <script>var customErrorMessages = {"fromtotimesame":"Fra- og til tid er ens","invalidemail":"Ugyldig e-mail adresse","emptyemail":"Indtast din e-mail adresse","emptyrequiredfield":"Felt må ikke være tomt","chooseoneormore":"Vælg én eller flere","enterminoneday":"Vælg én eller flere ugedage","enterfromorto":"Udfyld mindst ét af felterne","returntime":"Hjemrejse skal være efter udrejse","unknownstationfrom":"Ukendt station, indtast hvor du vil rejse fra","unknownstationto":"Ukendt station, indtast hvor du vil rejse til","fromtosame":"Fra- og til destination er ens","timeerror":"Fejl i tidsangivelse. Angiv f.eks. kl. 13:05","orangestationsonly":"Orange søgning virker kun hvis du indtaster stationer","emailsnotsimilar":"E-mail-adresserne er ikke ens.","passwordsnotsimilar":"Adgangskoderne er ikke ens.","required":"Dette felt skal udfyldes","wrongdateformat":"Dato skal angives i dette format: dd-mm-åååå","fieldsdoesnotmatch":"Felternes indhold skal være ens","minimumage":"Du skal være fyldt {0} år","cellphonenumber":"Indtast et gyldigt mobilnummer","maxlength10":"Indtast højst 10 tegn","maxlength40":"Indtast højst 40 tegn","maxlength60":"Indtast højst 60 tegn","numbersonly":"Indtast kun cifre","min4numbers":"Indtast mindst 4 cifre","exact4numbers":"Indtast 4 cifre","max4numbers":"Indtast højst 4 cifre","birthday":"Angiv din fødselsdato","stationnamenomatch":"Ugyldigt stationsnavn","invalidhomeaddress":"Adressen er ikke gyldig","customernotunder18":"Du er over 18 år og har derfor ikke brug for en værges samtykke.","invalidage":"Du kan ikke ændre din alder til at være under ##minormaxage## år uden først at fjerne samtykke nederst på denne side.","unknownerror":"Der opstod en fejl, prøv igen senere","min8numbers":"Indtast venligst 8 cifre","min16numbers":"Indtast venligst 16 cifre","cellphoneerror":"Telefonnummer skal være 8 cifre","passwordconfirmerror":"Adgangskoder skal være identiske","passworderror":"Adgangskoden skal være på mindst 8 tegn","postalcodeerror":"Postnummeret skal være 4 cifre","startdatefirstdaymontherror":"Den tidligste gyldighedsdato er den 1. i næste måned hvis i dag er før den 19. Ellers skal der lægges yderligere en måned til.","numberofzonesinputerror":"Valget af antal zoner og antallet af de ønskede zoner stemmer ikke overens","zonesinputerror":"Du har indtastet zoner på den forkerte måde (eksempel: 01, 02, 03)","loginwrongusernameorpassword":"Ugyldigt navn eller adgangskode","noaccessright":"Du har ikke rettigheder til at tilgå denne side. Log ud og forsøg igen","unknown":"Der opstod en fejl","unhandleexception":"Der opstod en fejl","usernotallowed":"Din alder er under den tilladte aldersgrænse","emailvalidation":{"enteremail":"Indtast e-mail adresse","entervalidemail":"Du skal indtaste en gyldig e-mail adresse","entersameemail":"Du skal indtaste den samme e-mail adresse i begge e-mail felter","entervalidcellphonenumber":"Indtast et gyldigt mobilnummer"},"phonenumbervalidation":{"invalidformat":"Indtast et gyldigt mobilnummer","cellphoneerror":"Telefonnummer skal være 8 cifre"},"login":{"noaccessright":"Du har ikke rettigheder til at tilgå denne side. Log ud og forsøg igen","wrongusernameorpassword":"Ugyldigt navn eller adgangskode","unexpectederror":"En uventet fejl opstod"},"businessportal":{"noaccessbusinesscard":"Brugeren har ikke adgang til virksomhedskort","noaccesscompanycard":"Brugeren har ikke adgang til erhvervskort","nocompanycardfound":"Ingen erhvervskort fundet"},"businessportaladddepartment":{"emailreceivernotconfigured":"E-mail-modtager ikke konfigureret. Kontakt venligst DSB"}};</script>
# <script type="text/javascript">
#             HAS_ALERT_NOTICE = true;
#         CURRENT_PAGEID = 12543;
#         SearchPageURL = '/sogning/';
#
#
#         SERVICE_ROOT = '/webservices';
#         window.IsCmsUser = false;
#         window.IsPrivateCustomer = false;
#         window.IsPrivateCustomerNonSyn = false;
#
#     </script>
# <script data-main="/html/dist/js/nddk-requirejs/app" src="/html/dist/js/nddk-requirejs/app.js?version=b6.0.647.7" type="text/javascript"></script>
# <script src="/html/dist/js/nddk-requirejs/businessportal/form-validator.js" type="text/javascript"></script>
# <script src="/html/src/js/interrail/travelsearch.js"></script>
# <link href="/html/media/fav/favicon.ico?v=2.0" rel="shortcut icon"/>
# <link href="/favicon.ico?v=2.0" rel="icon" type="image/x-icon"/>
# <link href="/html/media/fav/apple-touch-icon-57x57.png?v=2.0" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/html/media/fav/apple-touch-icon-114x114.png?v=2.0" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/html/media/fav/apple-touch-icon-72x72.png?v=2.0" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/html/media/fav/apple-touch-icon-144x144.png?v=2.0" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/html/media/fav/apple-touch-icon-60x60.png?v=2.0" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/html/media/fav/apple-touch-icon-120x120.png?v=2.0" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/html/media/fav/apple-touch-icon-76x76.png?v=2.0" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/html/media/fav/apple-touch-icon-152x152.png?v=2.0" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/html/media/fav/favicon-196x196.png?v=2.0" rel="icon" sizes="196x196" type="image/png"/>
# <link href="/html/media/fav/favicon-160x160.png?v=2.0" rel="icon" sizes="160x160" type="image/png"/>
# <link href="/html/media/fav/favicon-96x96.png?v=2.0" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/html/media/fav/favicon-16x16.png?v=2.0" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/html/media/fav/favicon-32x32.png?v=2.0" rel="icon" sizes="32x32" type="image/png"/>
# <meta content="#da532c" name="msapplication-TileColor"/>
# <meta content="/html/media/fav/mstile-144x144.png?v=2.0" name="msapplication-TileImage"/>
# <!-- Facebook domain verification - MAY NOT BE REMOVED -->
# <meta content="9ftmufasko3mrr43xsw0d4lur1q0pt" name="facebook-domain-verification"/>
# <link href="https://www.dsb.dk/find-produkter-og-services/dsb-rejsetidsgaranti/dsb-pendler-rejsetidsgaranti/kompensationsstorrelse/trafikdata-for-fr---ny/" rel="canonical"/>
# <!-- Cookie Saver Preload -->
# <script>
# (function(){function r(n,e,t){function i(o,u){if(!e[o]){if(!n[o]){var f="function"==typeof require&&require;if(!u&&f)return f(o,!0);if(a)return a(o,!0);var c=new Error("Cannot find module '"+o+"'");throw c.code="MODULE_NOT_FOUND",c}var s=e[o]={exports:{}};n[o][0].call(s.exports,function(r){var e=n[o][1][r];return i(e||r)},s,s.exports,r,n,e,t)}return e[o].exports}for(var a="function"==typeof require&&require,o=0;o<t.length;o++)i(t[o]);return i}return r})()({1:[function(r,n,e){"use strict";function t(r,n){return o(r)||a(r,n)||i()}function i(){throw new TypeError("Invalid attempt to destructure non-iterable instance")}function a(r,n){var e=[];var t=true;var i=false;var a=undefined;try{for(var o=r[Symbol.iterator](),u;!(t=(u=o.next()).done);t=true){e.push(u.value);if(n&&e.length===n)break}}catch(r){i=true;a=r}finally{try{if(!t&&o["return"]!=null)o["return"]()}finally{if(i)throw a}}return e}function o(r){if(Array.isArray(r))return r}(function(r,n){var e="3.2";var i=Date.now();if(!Object.entries){Object.entries=function(r){var n=Object.keys(r),e=n.length,t=new Array(e);while(e--){t[e]=[n[e],r[n[e]]]}return t}}function a(){var r="cs_test_cookie=1";var n=document.location.hostname.split(".");for(var e=n.length-1;e>=0;e--){var t=n.slice(e).join(".");document.cookie=r+";domain=."+t+";";if(document.cookie.indexOf(r)>-1){document.cookie=r.split("=")[0]+"=;domain=."+t+";expires=Thu, 01 Jan 1970 00:00:01 GMT;";return t}}return document.location.hostname}function o(r,n){var e=[n];var t=r.substring(0,r.length-n.length);if(t.length>0){var i=t.split(".");i.pop();var a=n;for(var o=i.length-1;o>=0;o--){a=i[o]+"."+a;e.push(a)}}return e}function u(r,n,e,t,i){var a=r+"="+n+";";if(e!==null){a+="expires="+e+";"}if(t!==null){a+="domain="+t+";"}if(i){a+="secure;"}a+="path=/;";document.cookie=a}var f=Date.now();var c=[];var s=document.cookie;if(!s){return}var l=a();var v=o(document.location.hostname,l);s=s.split(/; */);var h={};for(var d=0;d<s.length;d++){h[s[d].substring(0,s[d].indexOf("="))]=s[d].substring(s[d].indexOf("=")+1)}var g="_acs_";var p="_acs__acsr_";var b=[];Object.entries(h).forEach(function(r){var n=t(r,2),e=n[0],i=n[1];if(e.indexOf(g)===0){var a=true;for(var o in v){if(e===g+v[o]){a=false;break}}if(a){b.push(e);return}try{var s=JSON.parse(h[e]);if(s.c){var l=e.substring(g.length);for(var d=0,p=Object.entries(s.c);d<p.length;d++){var m=t(p[d],2),O=m[0],w=m[1];var x=parseInt(w.e,36)*1e3;if(!(O in h)&&x>f){u(O,w.v,new Date(x).toUTCString(),w.r?null:"."+l,w.s?true:false)}}}}catch(r){c.push({n:e,v:h[e],e:r})}}});b.forEach(function(r){var n=h[r];if(r.indexOf(p)===0){if(!(r.substring(p.length)in h)){u(r.substring(p.length),n,null,null,null);return}}if(r.indexOf(g)===0){if(!(r.substring(g.length)in h)){u(r.substring(g.length),n,null,l,null)}}});var m=Date.now();r.acqps={v:e,s:i,e:m,t:m-i,w:c}})(window)},{}]},{},[1]);
# </script>
# <!-- End Cookie Saver -->
# <script type="text/javascript">
#
#     window.dataLayer = window.dataLayer || [];
#     dataLayer.push({"event":"pageview.initial","pageType":"TwoColumnPage","pageLanguage":"da"});
#
#
#     var isDsbPlusLogout = localStorage.getItem("DsbPlusLogout");
#     if (isDsbPlusLogout) {
#         trackDsbPlus.signOut();
#         localStorage.removeItem("DsbPlusLogout");
#     }
#
# </script>
# <!-- Google Tag Manager -->
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({'gtm.start':new Date().getTime(), event: 'gtm.js'});
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#         j.async = true; j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-NXBBVS');
# </script>
# <!-- End Google Tag Manager -->
# </head>
# <body class="">
# <!-- New layout attempt-->
# <div class="page">
# <nav class="page-nav" id="page-nav">
# <div class="nav nav--primary">
# <ul>
# <li>
# <a class="" data-context="" data-status="" href="/">Find rejse og pris</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/trafikinformation/">Trafikinformation</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/kundeservice/">Kundeservice og kontakt</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/dsb-plus/">DSB Plus</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/dsb-erhverv/">Erhverv</a>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <ul>
# <li>
# <a data-context="#page-nav" data-status="toggleable" href="#nav-tickets-2409">Billetter og services</a>
# <ul data-status="collapsed" id="nav-tickets-2409">
# <li>
# <a class="" href="/kampagner/ungdomskort/">Ungdomskort</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/rejsekort/">Rejsekort</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-pendlerkort/">Pendler- og Periodekort</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/Pendler20/">Pendler20</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/#2385">Enkelt- og returbilletter</a>
# </li>
# <li>
# <a class="" href="/kampagner/dsb-1/">DSB 1'</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/orange/">DSB Orange</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/orange-fri/">DSB Orange Fri</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-udland/">Rejser til udlandet</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/#2393">Rejser over Øresund</a>
# </li>
# <li>
# <a class="nav__more" href="/find-produkter-og-services/">Find billetter og services</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <ul>
# <li>
# <a data-context="#page-nav" data-status="toggleable" href="#nav-tickets-44968">Rejsende</a>
# <ul data-status="collapsed" id="nav-tickets-44968">
# <li>
# <a class="" href="/rejsende/pendlere/">Pendlere</a>
# </li>
# <li>
# <a class="" href="/rejsende/born/">Børn</a>
# </li>
# <li>
# <a class="" href="/rejsende/unge-og-studerende/">Unge og studerende</a>
# </li>
# <li>
# <a class="" href="/rejsende/voksne/">Voksne</a>
# </li>
# <li>
# <a class="" href="/rejsende/aldre-og-pensionister/">Voksne 65+</a>
# </li>
# <li>
# <a class="" href="/dsb-erhverv/">Erhverv</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/cykelbillet-old/">Cykler</a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-gruppebillet/">Grupper</a>
# </li>
# <li>
# <a class="" href="/rejsende/turister/">Turister</a>
# </li>
# <li>
# <a class="" href="/rejsende/person-med-handicap/">Person med handicap</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <ul>
# <li>
# <a data-context="#page-nav" data-status="toggleable" href="#nav-tickets-36299">Planlagte sporarbejder</a>
# <ul data-status="collapsed" id="nav-tickets-36299">
# <li>
# <a class="" href="/trafikinformation/sydbanen/">Sydbanen</a>
# </li>
# <li>
# <a class="" href="/trafikinformation/slagelse/">Slagelse</a>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# <div class="nav nav--secondary">
# <ul>
# <li>
# <a class="" data-context="" data-status="" href="/trafikinformation/koereplaner/">Køreplaner</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/priser-og-zoner/">Priser og zoner</a>
# </li>
# <li>
# <a class="" data-context="" data-status="" href="/om-dsb/">Om DSB</a>
# </li>
# </ul>
# </div>
# <div class="nav nav--social">
# <div class="social-links">
# <ul>
# <li>
# <a class="facebook" data-context="" data-status="" href="https://www.facebook.com/dsb">Facebook</a>
# </li>
# <li>
# <a class="twitter" data-context="" data-status="" href="https://twitter.com/omDSB">Twitter</a>
# </li>
# <li>
# <a class="instagram" data-context="" data-status="" href="https://www.instagram.com/dsb.dk/">Instagram</a>
# </li>
# <li>
# <a class="youtube" data-context="" data-status="" href="https://www.youtube.com/user/DSBofficiel">YouTube</a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="login-dropdown page-login" id="page-login">
# <div id="js-curtain__mount"></div>
# <button class="login-btn login-dropdown__close-button" data-flyout="page-login"><span class="icon">LUK</span></button>
# </div>
# <header class="page-header">
# <div class="container">
# <div class="page-header__buttons">
# <a class="page-header__toggle-nav" data-flyout="page-nav" href="#">
# <span>Menu</span>
# </a>
# <a class="page-header__toggle-search" data-flyout="page-search" href="#">
# <span>Søg</span>
# </a>
# <a class="page-header__toggle-login" data-flyout="page-login" href="#">
# <span data-caption="Log ind" id="js-login-menu-item__mount"><span class="spinner spinner--small" style="display: inline-block"></span></span>
# </a>
# </div>
# <div class="page-header__logotype">
# <a href="/">DSB</a>
# </div>
# </div>
# </header>
# <!-- Searchbox for site search (Cludo) -->
# <nav class="page-search" id="page-search">
# <div class="container" id="cludo-search-nav">
# <form action="">
# <input autocomplete="off" placeholder="Søg her..." type="text"/>
# <button type="button">Søg</button>
# <a class="page-search__close" data-flyout="page-search">luk</a>
# </form>
# </div>
# </nav>
# <nav class="page-breadcrumb" id="breadCrmbNav">
# <div class="container">
# <ul>
# <li>
# <a href="/">Forside</a>
# </li>
# <li>
# <a href="/find-produkter-og-services/">Find billetter og services</a>
# </li>
# <li>
# <a href="/find-produkter-og-services/dsb-rejsetidsgaranti/">DSB Rejsetidsgaranti</a>
# </li>
# <li>
# <a href="/find-produkter-og-services/dsb-rejsetidsgaranti/dsb-pendler-rejsetidsgaranti/">DSB Pendler Rejsetidsgaranti</a>
# </li>
# <li>
# <a href="/find-produkter-og-services/dsb-rejsetidsgaranti/dsb-pendler-rejsetidsgaranti/kompensationsstorrelse/">Kompensationsstørrelse</a>
# </li>
# </ul>
# </div>
# </nav>
# <div class="content">
# <section class="fullwidthtop">
# </section>
# <div class="container">
# <div class="content__top">
# <div class="page-title">
# <h1>Trafikdata for Fjern- og regionaltog</h1>
# </div>
# </div>
# <div class="content__middle">
# <main class="content__main fullwidth">
# <div class="body text--wysiwyg">
# <p>Hver måned kan du følge med i, hvordan kundepunktligheden har været på din strækning. Til og med august 2015 er tallene opgjort på baggrund af punktlighed og pålidelighed. Fra 1. september 2015 er kompensationen på fjern- og regionaltog målestrækninger beregnet ud fra kundepunktlighedsmålene. Fra 13. december 2015 er kompensationen på Øresund målestrækninger beregnet på kundepunktlighed. <br/><a href="/om-dsb/virksomheden/kunderettidighed/">Læs mere om Kundepunktlighed </a></p>
# <p>Nedenfor kan du finde den måned, du har brug for, og så se de præcise tal for din strækning og hvad vi lover. Lever vi ikke op til vore mål på din valgte strækning, udbetaler vi en kontant kompensation.</p>
# <p>De viste tal er vejledende og baseret på at du køber kort gyldigt pr. kalendermåned (gyldigt fra første til og med sidste dag i en måned). Kort med anden gyldighed vil opnå andre resultater, fordi grundlaget for beregning er de daglige rapporteringer på valgte målestrækning, for antal rettidige, forsinkede og aflyste tog, som hver dag er vidt forskellige.</p>
# </div>
# <div><div>
# <section class="customer-service__contact">
# <div>
# <div class="container">
# <h2 class="text--title--h2">
#                     2021
#                 </h2>
# </div>
# </div>
# <div class="customer-service__contact-info show-all--open" style="display: block">
# <div class="container">
# <div class="customer-service__contact-info-table">
# <div class="customer-service__contact-info-column"><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             November
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>November 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">74,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">86,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">93,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">62,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">25,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">60,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">26,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">69,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">17,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">9,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">91,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København - Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Oktober
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>Oktober 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">89,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">94,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">64,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">23,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">68,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">19,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">59,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">28,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">74,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">73,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">14,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">71,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">97,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København - Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             September
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>September 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">73,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">14,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">95,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             August
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>August 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">70,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">16,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">65,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">22,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">68,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">19,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">67,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">20,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">90,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">83,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">86,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">89,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">94,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">78,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Juli
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>Juli 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">69,4,%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">18,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# ...
# <td headers="N1002E" width="57">98,3%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Odder - Aarhus - Grenaa</td>
# <td headers="N10022" width="74">95%</td>
# <td headers="N10026" width="57">98,6%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,1%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td><strong>DSB Øresund</strong></td>
# <td headers="N10022" width="74"><strong>Mål for rettidighed</strong></td>
# <td headers="N10026" width="57"><strong>Februar 14</strong></td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35"><strong>Kompensation</strong></td>
# </tr>
# <tr>
# <td><span>København - </span><span>Helsingør</span></td>
# <td headers="N10022" width="74"><span>92,0%</span></td>
# <td headers="N10026" width="57">96,0%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td><span>København - </span><span>CPH Lufthavn</span></td>
# <td headers="N10022" width="74"><span>92,0%</span></td>
# <td headers="N10026" width="57">93,1%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35"><span>0,0%</span></td>
# </tr>
# <tr>
# <td><span>København - </span><span>Malmø</span></td>
# <td headers="N10022" width="74"><span>92,0%</span></td>
# <td headers="N10026" width="57">92,0%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35"><span>0,0%</span></td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock theme-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Januar
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="width: 100%;">
# <tbody>
# <tr>
# <td><strong>DSB fjern- og regionaltog</strong></td>
# <td><strong>Mål for rettidighed</strong></td>
# <td><strong>Januar 14 </strong></td>
# <td><strong>Mål for pålidelighed</strong></td>
# <td><strong>Januar 14 </strong></td>
# <td><strong>Kompensation</strong></td>
# </tr>
# <tr>
# <td>København - Roskilde</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">96,3%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,6%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>København - Kalundborg</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">97,4%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,6%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>København - Nykøbing F</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">95,9%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,4%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Roskilde - Køge - Næstved</td>
# <td headers="N10022" width="74">97%</td>
# <td headers="N10026" width="57">98,4%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">98,4%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>København - Odense</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">94,6%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,9%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>København - Ringsted</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">95,7%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,6%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Odense - Fredericia</td>
# <td headers="N10022" width="74">92%</td>
# <td headers="N10026" width="57">
# <p>93,3%</p>
# </td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,6%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Odense - Svendborg</td>
# <td headers="N10022" width="74">97%</td>
# <td headers="N10026" width="57">97,1%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">
# <p>97,7%</p>
# </td>
# <td headers="N10033" width="35">2,0%</td>
# </tr>
# <tr>
# <td>Kolding - Padborg/Sønderborg</td>
# <td headers="N10022" width="74">93%</td>
# <td headers="N10026" width="57">86,9%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,5%</td>
# <td headers="N10033" width="35">7,0%</td>
# </tr>
# <tr>
# <td>Kolding - Esbjerg</td>
# <td headers="N10022" width="74">94%</td>
# <td headers="N10026" width="57">96,0%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,5%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Kolding - Fredericia - Vejle</td>
# <td headers="N10022" width="74">93%</td>
# <td headers="N10026" width="57">94,1%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,3%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Fredericia - Struer</td>
# <td headers="N10022" width="74">93%</td>
# <td headers="N10026" width="57">95,2%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">98,9%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Fredericia - Aarhus</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">94,0%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,5%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Aarhus - Aalborg</td>
# <td headers="N10022" width="74">90%</td>
# <td headers="N10026" width="57">97,6%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">99,8%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Aalborg - Frederikshavn</td>
# <td headers="N10022" width="74">95%</td>
# <td headers="N10026" width="57">96,5%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">97,5%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td>Odder - Aarhus - Grenaa</td>
# <td headers="N10022" width="74">95%</td>
# <td headers="N10026" width="57">96,7%</td>
# <td headers="N1002A" width="62">99%</td>
# <td headers="N1002E" width="57">98,4%</td>
# <td headers="N10033" width="35">0,0%</td>
# </tr>
# <tr>
# <td><strong>DSB Øresund</strong></td>
# <td headers="N10022" width="74"><strong>Mål for rettidighed</strong></td>
# <td headers="N10026" width="57"><strong>Januar 14</strong></td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35"><strong>Kompensation</strong></td>
# </tr>
# <tr>
# <td><span>København - </span><span>Helsingør</span></td>
# <td headers="N10022" width="74">92,0%</td>
# <td headers="N10026" width="57">94,6%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35"><span>0,0%</span></td>
# </tr>
# <tr>
# <td><span>København - </span><span>CPH Lufthavn</span></td>
# <td headers="N10022" width="74"><span>92,0%</span></td>
# <td headers="N10026" width="57">91,5%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35">1,0%</td>
# </tr>
# <tr>
# <td><span>København - </span><span>Malmø</span></td>
# <td headers="N10022" width="74"><span>92,0%</span></td>
# <td headers="N10026" width="57">90,0%</td>
# <td headers="N1002A" style="text-align: center;" width="62">-</td>
# <td headers="N1002E" style="text-align: center;" width="57">-</td>
# <td headers="N10033" width="35">2,0%</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </div>
# </section></div></div>
# </div>
# </div>
# </div>
# <div class="toggle__more load__more">
# <a></a>
# </div>
# </section>
# <script type="text/javascript">
#     require(["components/toggle-block/toggle-block__view"]);
# </script>
# </div></div>
# </main>
# </div>
# </div>
# <section class="fullwidthbottom">
# </section>
# </div>
# <footer class="page-footer">
# <div class="page-footer__top">
# <div class="container">
# <div class="page-footer__top-inner">
# <div class="nav nav--primary">
# <div class="nav__title"></div>
# <ul>
# <li>
# <a class="" href="/" target="" title="">
#                                                 Find rejse og pris
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/ud--se/" target="" title="">
#                                                 Læs "Ud &amp; Se"
#                                             </a>
# </li>
# <li>
# <a class="" href="/dsb-plus/" target="" title="">
#                                                 DSB Plus
#                                             </a>
# </li>
# <li>
# <a class="" href="/dsb-erhverv/" target="" title="">
#                                                 Erhverv
#                                             </a>
# </li>
# <li>
# <a class="" href="/kundeservice/" target="" title="">
#                                                 Kundeservice og kontakt
#                                             </a>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <div class="nav__title">Billetter og services</div>
# <ul>
# <li>
# <a class="" href="/kampagner/ungdomskort/" target="" title="">
#                                                 Ungdomskort
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/rejsekort/" target="" title="">
#                                                 Rejsekort
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-pendlerkort/" target="" title="">
#                                                 Pendler- og Periodekort
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/Pendler20/" target="" title="">
#                                                 Pendler20
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/#2385" target="" title="">
#                                                 Enkelt- og returbilletter
#                                             </a>
# </li>
# <li>
# <a class="" href="/kampagner/dsb-1/" target="" title="">
#                                                 DSB 1'
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/orange/" target="" title="">
#                                                 DSB Orange
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/orange-fri/" target="" title="">
#                                                 DSB Orange Fri
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-udland/" target="" title="">
#                                                 Rejser til udlandet
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/#2393" target="" title="">
#                                                 Rejser over Øresund
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/" target="" title="">
#                                                 Find billetter og services
#                                             </a>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <div class="nav__title">Trafik</div>
# <ul>
# <li>
# <a class="" href="/trafikinformation/" target="" title="">
#                                                 Trafikinformation
#                                             </a>
# </li>
# <li>
# <a class="" href="/trafikinformation/koereplaner/" target="" title="">
#                                                 Køreplaner
#                                             </a>
# </li>
# <li>
# <a class="" href="/trafikinformation/sporarbejde-2017/" target="" title="">
#                                                 Sporarbejder
#                                             </a>
# </li>
# <li>
# <a class="" href="/find-produkter-og-services/dsb-rejsetidsgaranti/" target="" title="">
#                                                 Rejsetidsgaranti
#                                             </a>
# </li>
# <li>
# <a class="" href="/trafikinformation/andringer-i-trafik-og-drift/andringer-i-trafik-og-drift/" target="" title="">
#                                                 Ændringer i trafik og drift
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/virksomheden/sikkerhed/" target="" title="">
#                                                 Sikkerhed
#                                             </a>
# </li>
# </ul>
# </div>
# <div class="nav nav--primary">
# <div class="nav__title">Om DSB</div>
# <ul>
# <li>
# <a class="" href="/om-dsb/job-i-dsb/" target="" title="">
#                                                 Job i DSB
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/samfundsansvar/" target="" title="">
#                                                 Samfundsansvar
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/baeredygtighed/" target="" title="">
#                                                 Bæredygtighed
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/" target="" title="">
#                                                 Om virksomheden
#                                             </a>
# </li>
# <li>
# <a class="" href="/om-dsb/virksomheden/forretningsbetingelser/rejseregler/" target="" title="">
#                                                 Rejse- og ordensregler
#                                             </a>
# </li>
# <li>
# <a class="" href="/kampagner/information-om-andringer/" target="" title="">
#                                                 Ændringer i kort og billetter
#                                             </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="page-footer__bottom">
# <div class="container">
# <div class="nav nav--secondary">
# <ul>
# <li>
# <a class="" href="/en/" target="" title="">In English</a>
# </li>
# <li>
# <a class="" href="/om-dsb/virksomheden/forretningsbetingelser/brug-af-cookies-pa-dsb.dk-og-dsbplus.dk/" target="" title="">Cookies på dsb.dk</a>
# </li>
# <li>
# <a class="" href="/om-dsb/virksomheden/forretningsbetingelser/persondata/" target="" title="">Persondata</a>
# </li>
# <li>
# <a class="" href="/konfiguration/global-menu-root-page/primar-gruppe-2/tilgangelighedserklaring/" target="" title="">Tilgængelighedserklæring</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <div class="modals" id="modals">
# <div class="modals__background">
# </div>
# </div>
# <script src="/html/dist/js/vendor.js?version=b6.0.647.7"></script>
# <script src="/html/dist/js/vl.js?version=b6.0.647.7"></script>
# <script src="/html/dist/js/dsb-app.js?version=b6.0.647.7"></script>
# <script src="//customer.cludo.com/scripts/bundles/search-script.min.js" type="text/javascript"></script>
# <script async="" defer="" src="https://www.google.com/recaptcha/api.js?hl=da"></script>
# <script>
#             var CludoSearch;
#             (function () {
#                 var cludoSettings = {
#                     customerId: 2014,
#                     engineId: 9676,
#                     searchUrl: "/sogning/",
#                     searchInputs: ["cludo-search-form-dsb", "cludo-search-nav"],
#                     initSearchBoxText: "",
#                     loading: "<span class='spinner .spinner--large'></span>",
#                     language: "da",
#                     richAutocomplete: true
#                 };
#                 CludoSearch= new Cludo(cludoSettings);
#                 CludoSearch.init();
#             })();
#     </script>
# </body>
# </html>

# %% [markdown]
# Ved at inspicere html data kan det ses, at html'en er opdelt i sektioner af måned og år. Yderligere er disse sektioner opdelt efter togstrækning, hvor der på hver strækning findes data for mål for kundepunktligheden, den faktiske punktlighed og kompensationen i procent.
#
# For at kunne navigere i html data'en, vil en lister over hver sektion af år blive gemt. Ved at inspicere ovenstående html ses det yderligere, at disse gemmes i en `section` med `class` kaldet `customer-service__contact`:

# %%
year_sections = soup.find_all('section', attrs={'class':'customer-service__contact'})

#eksempel html på seneste år printes:
year_sections[0]
# Out:
# <section class="customer-service__contact">
# <div>
# <div class="container">
# <h2 class="text--title--h2">
#                     2021
#                 </h2>
# </div>
# </div>
# <div class="customer-service__contact-info show-all--open" style="display: block">
# <div class="container">
# <div class="customer-service__contact-info-table">
# <div class="customer-service__contact-info-column"><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             November
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>November 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">74,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">86,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">93,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">62,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">25,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">60,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">26,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">69,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">17,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">9,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">91,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København - Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Oktober
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>Oktober 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">89,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">94,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">64,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">23,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">68,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">19,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">59,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">28,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">74,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">73,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">14,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">71,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">97,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København - Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             September
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>September 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">73,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">14,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">84,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">95,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             August
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>August 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">70,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">16,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,5%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">88,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">65,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">22,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">68,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">19,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">67,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">20,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">90,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">83,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">86,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,6%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">89,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">94,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">78,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">82,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">4,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Juli
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>Juli 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">69,4,%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">18,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">70,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">17,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">87,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,9%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">94,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">70,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">17,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">67,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">20,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">73,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Juni
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.337px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.525px;"><strong>Juni 21</strong></td>
# <td style="height: 18px; width: 112.925px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">78,0%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">9,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">82,7%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">86,6%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">89,9%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">76,3,%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">76,8%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">83,5%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">73,1%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">14,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">91,6%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">87,9%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">88,5%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">89,2%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">88,1%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">95,9%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">82,5%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">82,0%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">83,7%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">3,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Maj
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.337px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.525px;"><strong>Maj 21</strong></td>
# <td style="height: 18px; width: 112.925px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">75,6%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">81,3%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">83,6%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">4,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">91,7%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">74,7,%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">74,3%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">84,0%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">75,2%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">89,1%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">88,5%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">92,9%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">87,3%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">85,9%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">95,4%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">87,2%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">82,3%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 191.212px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.337px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.525px;">82,7%</td>
# <td headers="N10033" style="height: 18px; width: 112.925px;">5,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             April
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 202px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 69px;"><strong>April 21</strong></td>
# <td style="height: 18px; width: 113px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">80,4%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">80,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">84,9%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">92,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">77,3,%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">79,2%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">86,4%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">1,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">79,5%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">92,2%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">89,3%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">91,0%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">87,9%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">80,9%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">95,3%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">88,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">82,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">5,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">83,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">4,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Marts
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 202px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 69px;"><strong>Marts 21</strong></td>
# <td style="height: 18px; width: 113px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">88,9%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">89,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">89,1%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">89,1%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">87,5%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">87,9%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">82,2%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">90,0%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">95,5%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">92,2%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">84,5%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">3,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">92,2%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">90,3%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">95,8%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">89,1%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">75,6%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 224px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 202px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 69px;">80,5%</td>
# <td headers="N10033" style="height: 18px; width: 113px;">7,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Februar
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1">
# <tbody>
# <tr>
# <td><strong>Strækning</strong></td>
# <td><strong>Mål for kundepunktlighed</strong></td>
# <td><strong>Februar 21</strong></td>
# <td><strong>Kompensation</strong></td>
# </tr>
# <tr>
# <td>København -  Roskilde</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">84,9%</td>
# <td headers="N10033">2,0%</td>
# </tr>
# <tr>
# <td>København -  Kalundborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">86,8%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Nykøbing F</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">83,7%</td>
# <td headers="N10033">4,0%</td>
# </tr>
# <tr>
# <td>Køge - Næstved</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">81,3%</td>
# <td headers="N10033">6,0%</td>
# </tr>
# <tr>
# <td>København -  Odense</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">83,7%</td>
# <td headers="N10033">4,0%</td>
# </tr>
# <tr>
# <td>København -  Ringsted</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">81,9%</td>
# <td headers="N10033">5,0%</td>
# </tr>
# <tr>
# <td>Odense -  Fredericia</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">82,1%</td>
# <td headers="N10033">5,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">75,4%</td>
# <td headers="N10033">12,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Esbjerg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">89,0%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">86,9%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Fredericia -  Struer</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">83,5%</td>
# <td headers="N10033">4,0%</td>
# </tr>
# <tr>
# <td>Fredericia -  Aarhus</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">87,3%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Aarhus -  Aalborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">87,0%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Aalborg -  Frederikshavn</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">97,2%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Helsingør</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">88,2%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  CPH Lufthavn</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">85,3%</td>
# <td headers="N10033">2,0%</td>
# </tr>
# <tr>
# <td>København -  Malmø</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">81,2%</td>
# <td headers="N10033">6,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div><div><section>
# <div class="contentblock background-white inline-campaign">
# <div class="container">
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             Januar
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1">
# <tbody>
# <tr>
# <td><strong>Strækning</strong></td>
# <td><strong>Mål for kundepunktlighed</strong></td>
# <td><strong>Januar 21</strong></td>
# <td><strong>Kompensation</strong></td>
# </tr>
# <tr>
# <td>København -  Roskilde</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">88,1%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Kalundborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">91,9%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Nykøbing F</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">89,9%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Køge - Næstved</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">96,2%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Odense</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">86,0%</td>
# <td headers="N10033">1,0%</td>
# </tr>
# <tr>
# <td>København -  Ringsted</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">85,8%</td>
# <td headers="N10033">1,0%</td>
# </tr>
# <tr>
# <td>Odense -  Fredericia</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">88,2%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">88,5%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Esbjerg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">95,2%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">92,8%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Fredericia -  Struer</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">91,9%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Fredericia -  Aarhus</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">91,4%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Aarhus -  Aalborg</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">92,3%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>Aalborg -  Frederikshavn</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">95,7%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  Helsingør</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">87,5%</td>
# <td headers="N10033">0,0%</td>
# </tr>
# <tr>
# <td>København -  CPH Lufthavn</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">85,9%</td>
# <td headers="N10033">1,0%</td>
# </tr>
# <tr>
# <td>København -  Malmø</td>
# <td headers="N1002A">86,8%</td>
# <td headers="N1002E">85,1%</td>
# <td headers="N10033">2,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>
# </div>
# </div>
# </section></div></div>
# </div>
# </div>
# </div>
# <div class="toggle__more load__more">
# <a></a>
# </div>
# </section>

# %% [markdown]
# #### Årstal
# Under hver sektion af år gemmes selve årstallet som tekst i en header `h2` med `class` `text--title--h2`. Dog gemmes denne `string` med tomme linjer før og efter, som skal fjernes.
#
# Nedenfor ses eksempel:

# %%
# eksempel på udtræk af årstal:
year_sections[0]\
        .find('h2',attrs={'class':'text--title--h2'})\
        .text\
        .replace("\r\n","")\
        .strip()
# Out:
# '2021'

# %% [markdown]
# #### Måned
# Under hvert år findes en række sektioner af månedsdata i en hver sin `div` container kaldet `inline-campaign__content`. Et eksempel på dette følger:

# %%
# eksempel på html-udtræk på seneste opgjorte måned i 2021:
year_sections[0].find_all('div', attrs={'class':'inline-campaign__content'})[0]
# Out:
# <div class="inline-campaign__content">
# <div class="inline-campaign__title">
# <h2>
#                             November
#                         </h2>
# </div>
# <div class="inline-campaign__body text--wysiwyg">
# <table border="1" style="height: 324px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;"><strong>Strækning</strong></td>
# <td style="height: 18px; width: 186.8px;"><strong>Mål for kundepunktlighed</strong></td>
# <td style="height: 18px; width: 64.4px;"><strong>November 21</strong></td>
# <td style="height: 18px; width: 114px;"><strong>Kompensation</strong></td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Kalundborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">74,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">13,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Nykøbing F</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">86,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Køge - Næstved</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">93,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Odense</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">62,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">25,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Ringsted</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">72,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">15,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Odense -  Fredericia</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">60,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">26,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Padborg/ Sønderborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">69,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">17,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Esbjerg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,8%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">9,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Kolding -  Fredericia - Vejle</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">81,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">6,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Struer</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,4%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Fredericia -  Aarhus</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">79,3%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">8,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aarhus -  Aalborg</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">85,7%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">2,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">Aalborg -  Frederikshavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">91,1%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">0,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København - Helsingør</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">76,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">11,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  CPH Lufthavn</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">77,0%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">10,0%</td>
# </tr>
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Malmø</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">80,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">7,0%</td>
# </tr>
# </tbody>
# </table>
# <p> </p>
# </div>
# </div>

# %% [markdown]
# Hertil kan det aflæses, at måneden som tekst kan findes i noden `h2` og at denne ligeledes som årstallet gemmes som en string med tomme linjer før og efter, som skal fjernes.
#
# Et eksempel på dette følger:

# %%
#eksempel på udtræk af måned i tekst
year_sections[0]\
    .find_all('div', attrs={'class':'inline-campaign__content'})[0]\
    .find('h2')\
    .text\
    .replace("\r\n","")\
    .strip()
# Out:
# 'November'

# %% [markdown]
# #### Strækning
# Det er nu muligt at finde de relevante data på de enkelte strækinger. Det kan af ovenstående html udledes, at den ønskede data gemmes i en node `tr`. Disse er hver række i den ønskede data. Den første række indeholder overskrifter og må derfor springes over.
#
# Et eksempel på html-udtræk af første strækning følger:

# %%
year_sections[0]\
        .find_all('div', attrs={'class':'inline-campaign__content'})\
        [0]\
        .find_all('tr')[1]
# Out:
# <tr style="height: 18px;">
# <td style="height: 18px; width: 190.8px;">København -  Roskilde</td>
# <td headers="N1002A" style="height: 18px; width: 186.8px;">86,8%</td>
# <td headers="N1002E" style="height: 18px; width: 64.4px;">75,2%</td>
# <td headers="N10033" style="height: 18px; width: 114px;">12,0%</td>
# </tr>

# %% [markdown]
# #### Udtræk af data
# Det er nu muligt at få den ønskede data hentet ud. Det kan udledes, at af ovenstående node `tr` har fire *children* af noden `td`. Disse indeholder i rækkefølge:
# 1. Navn på strækning
# 2. Mål for kundepunktlighed
# 3. Den faktiske punktlighed på strækningen i det pågældende år og måned
# 4. Kompensation i procent
#
# Nedenfor følger et eksempel på hvordan disse data hentes ud:

# %%
# eksempel udtræk fra september 2021
test_okt21 = year_sections[0]\
                .find_all('div', attrs={'class':'inline-campaign__content'})\
                [0]\
                .find_all('tr')[1]\
                .find_all('td')

print("Eksempel udtræk:")
print("Strækning: " + test_okt21[0].text)
print("Mål for punktlighed: " + test_okt21[1].text)
print("Faktisk punktlighed: " + test_okt21[2].text)
print("Kompensation: " + test_okt21[3].text)
# Out:
# Eksempel udtræk:
# Strækning: København -  Roskilde
# Mål for punktlighed: 86,8%
# Faktisk punktlighed: 75,2%
# Kompensation: 12,0%

# %% [markdown]
# ### Eksport til dataframe
# Ovenstående gør det nu muligt at udtrække data'en og gemme i et dataframe. Den data, der ønskes udtrækket, er følgende:
# - Årstal
# - Måned
# - Mål for kundepunktlighed
# - Den faktiske punktlighed på strækningen
# - Kompensation i procent
#
# Dette gemmes i et samlet dataframe.

# %%
#initiér tid til debug
start_time = time.time()

#en tom liste oprettes for hvert af de ønskede data, der hver skal have sin egen kolonne i dataframet
year = []
month = []
train_line = []
goal = []
actual = []
compensation = []

#midlertiddige variable på årstal & måned oprettes til brug i loop
this_year = ""
this_month = ""

#et loop startes for hvert sektion af år på hjemmesiden 
#disse er allerede hentet og gemt i en liste kaldet year_sections
for i in range(len(year_sections)):
    #årstalet gemmes
    this_year = year_sections[i]\
                    .find('h2',attrs={'class':'text--title--h2'})\
                    .text\
                    .replace("\r\n","")\
                    .strip()
    
    #en liste over hver måned for pågældende år
    month_sections = year_sections[i].find_all('div', attrs={'class':'inline-campaign__content'})
    
    #hver måned loopes igennem
    for j in range (len(month_sections)):
        #måneden gemmes
        this_month = month_sections[j]\
                        .find('h2')\
                        .text\
                        .replace("\r\n","")\
                        .strip()
        
        #Det er nu muligt at loope yderligere gennem hver strækning
        #en liste over toglinjer defineres
        line_sections = month_sections[j].find_all('tr')
        
        #disse loopes igennem, hvor første springes over, da denne indholder kolonne navne
        for k in range (len(line_sections)-1):
            #det er nu muligt at udtrække den ønskede data
            #disse ligger i 4 children under toglinjen, som gemmes i en liste:
            data_sections = line_sections[k+1].find_all('td')
            
            #dataen kan nu gemmes
            year.append(this_year)
            month.append(this_month)
            train_line.append(data_sections[0].text)
            goal.append(data_sections[1].text)
            actual.append(data_sections[2].text)
            compensation.append(data_sections[3].text)
                

#DataFrame konstrueres
df_punktlighed = pd.DataFrame({'Årstal':year,
                               'Måned':month,
                               'Togstrækning':train_line,
                               'Målsætning':goal,
                               'Punktlighed':actual,
                               'Kompensation':compensation})
#tid printes
print("--- %s seconds ---" % round((time.time() - start_time),2))
# Out:
# --- 0.26 seconds ---

# %% [markdown]
# Dataframet er nu konstrueret, og inspiceres:

# %%
df_punktlighed
# Out:
#      Årstal     Måned              Togstrækning           Målsætning  \
# 0      2021  November     København -  Roskilde                86,8%
# 1      2021  November   København -  Kalundborg                86,8%
# 2      2021  November   København -  Nykøbing F                86,8%
# 3      2021  November            Køge - Næstved                86,8%
# 4      2021  November       København -  Odense                86,8%
# ...     ...       ...                       ...                  ...
# 1750   2014    Januar   Odder - Aarhus - Grenaa                  95%
# 1751   2014    Januar               DSB Øresund  Mål for rettidighed
# 1752   2014    Januar     København - Helsingør                92,0%
# 1753   2014    Januar  København - CPH Lufthavn                92,0%
# 1754   2014    Januar         København - Malmø                92,0%
#
#      Punktlighed Kompensation
# 0          75,2%        12,0%
# 1          74,2%        13,0%
# 2          86,8%         0,0%
# 3          93,1%         0,0%
# 4          62,2%        25,0%
# ...          ...          ...
# 1750       96,7%          99%
# 1751   Januar 14            -
# 1752       94,6%            -
# 1753       91,5%            -
# 1754       90,0%            -
#
# [1755 rows x 6 columns]

# %% [markdown]
# #### Fjern af årstal
# Det ses dog, at i årene 2014 og 2015 blev togpunktligheden opgjort på anden vis end de efterfølgende år. Dette er ikke blot en formatændring. Derfor er det ikke muligt at sammenligne 2014 og 2015 med de øvrige år og de må derfor fjernes:

# %%
#liste med årstal der skal fjernes:
del_years = ["2014", "2015"]

#årstalene fjernes fra dataframe'et
df_punktlighed = df_punktlighed[df_punktlighed.Årstal.isin(del_years) == False]

#dataframe printes
df_punktlighed
# Out:
#      Årstal     Måned              Togstrækning Målsætning Punktlighed  \
# 0      2021  November     København -  Roskilde      86,8%       75,2%
# 1      2021  November   København -  Kalundborg      86,8%       74,2%
# 2      2021  November   København -  Nykøbing F      86,8%       86,8%
# 3      2021  November            Køge - Næstved      86,8%       93,1%
# 4      2021  November       København -  Odense      86,8%       62,2%
# ...     ...       ...                       ...        ...         ...
# 1270   2016    Januar   Aalborg - Frederikshavn      81,8%       94,1%
# 1271   2016    Januar   Odder - Aarhus - Grenaa      81,8%       90,9%
# 1272   2016    Januar     København - Helsingør      81,8%       73,1%
# 1273   2016    Januar  København - CPH Lufthavn      81,8%       78,2%
# 1274   2016    Januar         København - Malmø      81,8%       74,7%
#
#      Kompensation
# 0           12,0%
# 1           13,0%
# 2            0,0%
# 3            0,0%
# 4           25,0%
# ...           ...
# 1270         0,0%
# 1271         0,0%
# 1272         9,0%
# 1273         4,0%
# 1274         8,0%
#
# [1275 rows x 6 columns]

# %% [markdown]
# #### Omkod af årstal
# Årstalene omkodes fra string til int:

# %%
df_punktlighed["Årstal"] = df_punktlighed["Årstal"].astype(int)
# Out:
# <ipython-input-12-90ae0ce28e11>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_punktlighed["Årstal"] = df_punktlighed["Årstal"].astype(int)

# %% [markdown]
# #### Omkodning af procent
# Rækkerne med procent omkodes til float, så der kan regnes på procenterne.
#
# Der dog enkelte slå fejl i den data som er hentet fra DSB's hjemmeside:

# %%
print(df_punktlighed[(df_punktlighed == '69,4,%').any(axis=1)])
print(df_punktlighed[(df_punktlighed == '76,3,%').any(axis=1)])
print(df_punktlighed[(df_punktlighed == '74,7,%').any(axis=1)])
print(df_punktlighed[(df_punktlighed == '77,3,%').any(axis=1)])
# Out:
#     Årstal Måned         Togstrækning Målsætning Punktlighed Kompensation
# 72    2021  Juli  København -  Odense      86,8%      69,4,%        18,0%
#     Årstal Måned         Togstrækning Målsætning Punktlighed Kompensation
# 89    2021  Juni  København -  Odense      86,8%      76,3,%        11,0%
#      Årstal Måned         Togstrækning Målsætning Punktlighed Kompensation
# 106    2021   Maj  København -  Odense      86,8%      74,7,%        13,0%
#      Årstal  Måned         Togstrækning Målsætning Punktlighed Kompensation
# 123    2021  April  København -  Odense      86,8%      77,3,%        10,0%

# %% [markdown]
# Fejlene rettes manuelt:

# %%
df_punktlighed.at[72, "Punktlighed"] = '69,4%'
df_punktlighed.at[89, "Punktlighed"] = '76,3%'
df_punktlighed.at[106, "Punktlighed"] = '74,7%'
df_punktlighed.at[123, "Punktlighed"] = '77,3%'

# %% [markdown]
# Der ses også, at i en enkelt strækning i 2018 blev indsat togbusser, hvorfor togpunktlighed ikke kunne måles.

# %%
df_punktlighed[(df_punktlighed == '\xa0-').any(axis=1)]
# Out:
#      Årstal Måned             Togstrækning Målsætning Punktlighed Kompensation
# 724    2018  Juli  København -  Helsingør*      82,9%           -            -

# %% [markdown]
# Denne række fjernes fra vores data:

# %%
df_punktlighed = df_punktlighed.drop(index=724)

# %% [markdown]
# Der ses dog stadig rækker, som indeholder indtastningsfejl. Disse fejl omfatter:
# - Linjeskift
# - Mellemrum
#
# Disse fjernes også fra indtastningerne.
#
# Rækkerne med procent kan nu omkodes til floats, og dermed procenter:

# %%
# Liste over kolonnenavne
omkod_list = ["Målsætning", "Punktlighed", "Kompensation"]

#df_test = df_punktlighed.copy()

# Hver kolonne loopes igennem og omkodes til float:
for i in range(len(omkod_list)):
    df_punktlighed[omkod_list[i]] = df_punktlighed[omkod_list[i]].\
                                                        str.\
                                                        replace('\n', '').\
                                                        str.\
                                                        replace('\xa0', '').\
                                                        str.\
                                                        rstrip('%').\
                                                        str.\
                                                        replace(',', '.').\
                                                        astype('float') / 100.0

df_punktlighed
# Out:
#       Årstal     Måned              Togstrækning  Målsætning  Punktlighed  \
# 0       2021  November     København -  Roskilde       0.868        0.752
# 1       2021  November   København -  Kalundborg       0.868        0.742
# 2       2021  November   København -  Nykøbing F       0.868        0.868
# 3       2021  November            Køge - Næstved       0.868        0.931
# 4       2021  November       København -  Odense       0.868        0.622
# ...      ...       ...                       ...         ...          ...
# 1270    2016    Januar   Aalborg - Frederikshavn       0.818        0.941
# 1271    2016    Januar   Odder - Aarhus - Grenaa       0.818        0.909
# 1272    2016    Januar     København - Helsingør       0.818        0.731
# 1273    2016    Januar  København - CPH Lufthavn       0.818        0.782
# 1274    2016    Januar         København - Malmø       0.818        0.747
#
#       Kompensation
# 0             0.12
# 1             0.13
# 2             0.00
# 3             0.00
# 4             0.25
# ...            ...
# 1270          0.00
# 1271          0.00
# 1272          0.09
# 1273          0.04
# 1274          0.08
#
# [1274 rows x 6 columns]

# %% [markdown]
# #### Navn på togstrækninger
# Det indtastede navn for hver enkelt togstrækning indeholder også fejl. Disse fejl omfatter:
# - Dobbelt mellemrum
#
# Disse fejl vil nu blive rettet

# %%
#dobbelt mellemrum fjernes
df_punktlighed["Togstrækning"] = df_punktlighed["Togstrækning"].\
                                                                str.\
                                                                replace(' ', '').\
                                                                str.\
                                                                replace('\xa0', '')

# %% [markdown]
# #### Måneder
# Under kolonnen "Måned" er december i 2018 ikke blot indtastet som "December", men "December 2018". Dette er den eneste måned med denne fejl, så her fjernes 2018 fra string:

# %%
df_punktlighed["Måned"] = df_punktlighed["Måned"].\
                                                str.\
                                                replace(' 2018', '')

# %% [markdown]
# ### Beregninger
# Dataframet er nu konstrueret og vi kan nu begynder at foretage beregninger.

# %% [markdown]
# ### Divergens fra målsætning
# Den faktiske punktlighed fratrækkes målet for punktlighed, for at skabe en mål afvigelsen af togpunktligheden:

# %% [markdown]
# #### Afvigelse på tværs af år

# %%
df_punktlighed["Afvigelse"] = df_punktlighed["Punktlighed"]-df_punktlighed["Målsætning"]
df_punktlighed
# Out:
#       Årstal     Måned           Togstrækning  Målsætning  Punktlighed  \
# 0       2021  November     København-Roskilde       0.868        0.752
# 1       2021  November   København-Kalundborg       0.868        0.742
# 2       2021  November    København-NykøbingF       0.868        0.868
# 3       2021  November           Køge-Næstved       0.868        0.931
# 4       2021  November       København-Odense       0.868        0.622
# ...      ...       ...                    ...         ...          ...
# 1270    2016    Januar  Aalborg-Frederikshavn       0.818        0.941
# 1271    2016    Januar    Odder-Aarhus-Grenaa       0.818        0.909
# 1272    2016    Januar    København-Helsingør       0.818        0.731
# 1273    2016    Januar  København-CPHLufthavn       0.818        0.782
# 1274    2016    Januar        København-Malmø       0.818        0.747
#
#       Kompensation  Afvigelse
# 0             0.12     -0.116
# 1             0.13     -0.126
# 2             0.00      0.000
# 3             0.00      0.063
# 4             0.25     -0.246
# ...            ...        ...
# 1270          0.00      0.123
# 1271          0.00      0.091
# 1272          0.09     -0.087
# 1273          0.04     -0.036
# 1274          0.08     -0.071
#
# [1274 rows x 7 columns]

# %%
split_vars = ['Årstal'] 
apply_vars = ['Målsætning', 'Punktlighed', 'Kompensation']
apply_fcts = ['mean']

df_illu = df_punktlighed.groupby(split_vars)[apply_vars].agg(apply_fcts)

x_labels = df_illu.index.get_level_values(0)
l_mål = list(df_illu['Målsætning']['mean'])
l_punkt = list(df_illu['Punktlighed']['mean'])


values1 = np.array(l_mål)
values2 = np.array(l_punkt)
x = np.arange(len(x_labels))

n_values = 2
width = 0.35

# plot
fig, ax = plt.subplots(figsize=(11,7))
rects1 = ax.bar(x-width/2, l_mål, width, label='Målsætning')
rects2 = ax.bar(x+width/2, l_punkt, width, label='Punktlighed')
#ax.bar(x, values1, width, color='b')
#ax.bar(x+width, values2, width, color='g')

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
        
# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           fontsize='16', \
           horizontalalignment='center', \
           verticalalignment='top')

# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# zoom ind
plt.ylim([0.65, 0.9])

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj grid
plt.grid(axis = 'y')

# tilføj titel
ax.set_title('Togpunklighed', \
             fontweight='bold', \
             fontsize='16')

# tilføj legend
plt.legend(loc="upper left", prop={'size': 16})

# %% [markdown]
# #### Afvigelse på tværs af kvartaler
# Et variabel for kvartal indsættes i datasættet:

# %%
# funktion oprettes til formålet:
q1 = ['Januar', 'Februar', 'Marts']
q2 = ['April', 'Maj', 'Juni']
q3 = ['Juli', 'August', 'September']
q4 = ['Oktober', 'November', 'December']

def calc_quarter(row):
    month = row["Måned"]
    year = str(row['Årstal'])
    if any(month in m for m in q1):
        return year + " Q1"
    if any(month in m for m in q2):
        return year + " Q2"
    if any(month in m for m in q3):
        return year + " Q3"
    if any(month in m for m in q4):
        return year + " Q4"

# funktionen køres på dataframe og gemmes i ny kolonne
df_punktlighed["Kvartal"] = df_punktlighed.apply(calc_quarter, axis=1)

# inspiceres
df_punktlighed
# Out:
#       Årstal     Måned           Togstrækning  Målsætning  Punktlighed  \
# 0       2021  November     København-Roskilde       0.868        0.752
# 1       2021  November   København-Kalundborg       0.868        0.742
# 2       2021  November    København-NykøbingF       0.868        0.868
# 3       2021  November           Køge-Næstved       0.868        0.931
# 4       2021  November       København-Odense       0.868        0.622
# ...      ...       ...                    ...         ...          ...
# 1270    2016    Januar  Aalborg-Frederikshavn       0.818        0.941
# 1271    2016    Januar    Odder-Aarhus-Grenaa       0.818        0.909
# 1272    2016    Januar    København-Helsingør       0.818        0.731
# 1273    2016    Januar  København-CPHLufthavn       0.818        0.782
# 1274    2016    Januar        København-Malmø       0.818        0.747
#
#       Kompensation  Afvigelse  Kvartal
# 0             0.12     -0.116  2021 Q4
# 1             0.13     -0.126  2021 Q4
# 2             0.00      0.000  2021 Q4
# 3             0.00      0.063  2021 Q4
# 4             0.25     -0.246  2021 Q4
# ...            ...        ...      ...
# 1270          0.00      0.123  2016 Q1
# 1271          0.00      0.091  2016 Q1
# 1272          0.09     -0.087  2016 Q1
# 1273          0.04     -0.036  2016 Q1
# 1274          0.08     -0.071  2016 Q1
#
# [1274 rows x 8 columns]

# %% [markdown]
# Punktlighed og målsætning for hvert kvartal plottes.
#
# Nedenfor eksempel for år 2018:

# %%
split_vars = ['Kvartal'] 
apply_vars = ['Målsætning', 'Punktlighed']
apply_fcts = ['mean']

df_temp = df_punktlighed[df_punktlighed["Årstal"]==2018]
df_illu = df_temp.groupby(split_vars)[apply_vars].agg(apply_fcts)

x_labels = df_illu.index.get_level_values(0)
l_mål = list(df_illu['Målsætning']['mean'])
l_punkt = list(df_illu['Punktlighed']['mean'])


values1 = np.array(l_mål)
values2 = np.array(l_punkt)
x = np.arange(len(x_labels))

width = 0.35

# plot
fig, ax = plt.subplots(figsize=(10,7))
rects1 = ax.bar(x-width/2, l_mål, width, label='Målsætning')
rects2 = ax.bar(x+width/2, l_punkt, width, label='Punktlighed')

# funktion der tilføjer procent over søjlerne
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
        
# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           fontsize='16', \
           horizontalalignment='center', \
           verticalalignment='top')

# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# zoom ind
plt.ylim([0.65, 0.9])

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj grid
plt.grid(axis = 'y')

# tilføj titel
ax.set_title('Togpunklighed i 2018', \
             fontweight='bold', \
             fontsize='16')

# tilføj legend
plt.legend(loc="upper left", prop={'size': 16})

# %% [markdown]
# ## Togpunktlighed: Web scrape fra Banedanmark
# Historisk data over togpunktlighed og kompensation hentes fra ligeledes fra Banedanmarks's hjemmeside.
#
# Ved at inspicere hjemmesiden kan det ses, at data'en er opdelt i måned og år. Yderligere er der data på hvem er henholdsvis Banedanmark, DSB eller eksterne forhold, der har ansvaret for, at et tog ikke kom til tiden.
#
# Dette data vil blive hentet og gemt i et dataframe

# %% [markdown]
# ### Den relevante data lokores i html fra hjemmeside
# Ved brug af requestsog beautifulsoup vil hjemmesidens html data blive hentet og parset, hvorefter den relevante data vil blive gemt i et pandas dataframe.
#
# Hvert år har sin egen url.
#
# Først hentes html fra den relevante side hos Banedanmark og gemmes med beautifulsoup. Derefter printes html, så hjemmesidens opbygning kan aflæses og den relevante data kan lokeres:

# %%
# URL til data'en på Banedanmark's hjemmeside indlæses, hentes, og gemmes som beautifulsoup objekt:
# i eksemplet her bruges år 2021
url = "https://www.bane.dk/da/Om-Banedanmark/Saadan-koerer-togene/Fjernbanen-2021"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

#html data printes og inspiceres
soup
# Out:
# <!DOCTYPE HTML>
#
# <html lang="da">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script data-culture="DA" id="CookieConsent" src="https://policy.app.cookieinformation.com/uc.js" type="text/javascript"></script>
# <!-- Google Tag Manager -->
# <script>
# (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;
# 	j.setAttribute('data-category-consent', 'cookie_cat_statistic');
# 	j.setAttribute('data-consent-src', 'https://www.googletagmanager.com/gtm.js?id=' + i + dl);
# 	f.parentNode.insertBefore(j, f);
# 	})(window,document,'script','dataLayer','GTM-P4BBKVR');</script>
# <!-- End Google Tag Manager -->
# <link href="/-/design/dist/global/styles/print---b5d14345.css" rel="stylesheet" type="text/css"/>
# <link href="/-/design/dist/global/styles/rte---e4328998.css" rel="stylesheet" type="text/css"/>
# <link href="/-/design/dist/global/styles/style---601dd0f6.css" rel="stylesheet" type="text/css"/>
# <meta content="{A76FB5F1-ACD0-4550-81C9-8B23879CCFA1}" name="itemid"/>
# <link href="https://www.bane.dk/da/Om-Banedanmark/Saadan-koerer-togene/Fjernbanen-2021" rel="canonical">
# <meta content="" name="description"/>
# <title>
# Fjernbanen 2021 | Banedanmark</title>
# <!--
# 	<PageMap>
# 		<DataObject type="document">
# 			<Attribute name="taxonomy">Borger</Attribute>
# 			<Attribute name="taxonomy">Maalgruppe</Attribute>
# 			<Attribute name="taxonomy">Indholdstype</Attribute>
# 		</DataObject>
# 	</PageMap>
# 	-->
# <!-- Twitter Card data -->
# <meta content="Fjernbanen 2021" name="twitter:title"/>
# <meta content="" name="twitter:description"/>
# <meta content="https://www.bane.dk/-/media/Bane/Presse/Pressemeddelelser-billeder/Traengsel-billede.jpg?h=675&amp;w=1200&amp;la=da&amp;useCustomFunctions=1¢erCrop=1&amp;hash=E775D4BF490959C10B1CC8C4F028A7925384D234" name="twitter:image"/>
# <!-- Open Graph data -->
# <meta content="Fjernbanen 2021" property="og:title">
# <meta content="article" property="og:type">
# <meta content="https://www.bane.dk/da/Om-Banedanmark/Saadan-koerer-togene/Fjernbanen-2021" property="og:url">
# <meta content="https://www.bane.dk/-/media/Bane/Presse/Pressemeddelelser-billeder/Traengsel-billede.jpg?h=675&amp;w=1200&amp;la=da&amp;useCustomFunctions=1¢erCrop=1&amp;hash=E775D4BF490959C10B1CC8C4F028A7925384D234" property="og:image">
# <meta content="" property="og:description"/>
# <meta content="website" property="og:site_name"/>
# <meta content="follow, index" name="robots"/>
# <link href="/apple-touch-icon.png?v=2" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon-32x32.png?v=2" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon-16x16.png?v=2" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/site.webmanifest?v=2" rel="manifest"/>
# <link color="#000000" href="/safari-pinned-tab.svg?v=2" rel="mask-icon"/>
# <link href="/favicon.ico?v=2" rel="shortcut icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="#ffffff" name="theme-color"/>
# </meta></meta></meta></meta></link></head>
# <body class="site--theme-one">
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe data-category-consent="cookie_cat_statistic" data-consent-src="https://www.googletagmanager.com/ns.html?id=GTM-P4BBKVR" height="0" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script src="/dist/global/scripts/components/reveal/onbeforerender.js"></script>
# <div class="site__svgsprites hidden">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><svg data-name="Layer 1" id="arrow" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M56.87 0l26.66 50.37L56.87 100h-40.4L43 50.37 16.47 0z"></path></svg><svg id="arrow-small" viewbox="0 0 5.28 10.37" xmlns="http://www.w3.org/2000/svg"><path d="M2.18 10.37H0l3-5.18L0 0h2.18l3.1 5.19z"></path></svg><svg data-name="Layer 1" id="close" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M11.392-.006L100 88.602 88.608 99.993 0 11.386z"></path><path d="M-.006 88.608L88.602 0l11.391 11.392L11.386 100z"></path></svg><svg data-name="Layer 1" id="download" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M100 40.4L49.63 67.07 0 40.4V0l49.63 26.56L100 0zM0 84h100v16H0zm16-16v16H0V68zm84 0v16H84V68z"></path></svg><svg data-name="Layer 1" id="mail" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M92.6 12.58H7.4A7.4 7.4 0 000 20v60.32a7.1 7.1 0 007.1 7.1h85.5A7.4 7.4 0 00100 80V20a7.4 7.4 0 00-7.4-7.42zM90 30.57A7.08 7.08 0 0185.8 37L52.89 51.76a7.09 7.09 0 01-5.79 0L14.2 37a7.08 7.08 0 01-4.2-6.43v-8h80z"></path></svg><svg data-name="Layer 1" id="menu-burger" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><defs><style>.fcls-1{fill:none;stroke:#000;stroke-miterlimit:10;stroke-width:16px}</style></defs><path class="fcls-1" d="M0 13.59h100M0 49.43h100m0 36.98H60.48L25.1 49.98"></path></svg><svg id="pin" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><style></style><path d="M50 0C27.9 0 9.9 18 9.9 40.1c0 2.5.2 5.1.7 7.5 0 .1.1.6.3 1.3.6 2.7 1.5 5.4 2.7 7.9C17.9 67 27.4 82.6 48.2 99.4c.5.4 1.2.6 1.8.6s1.3-.2 1.8-.6C72.6 82.6 82.1 67 86.4 56.9c1.2-2.5 2.1-5.2 2.7-7.9.2-.8.3-1.2.3-1.3.5-2.5.7-5 .7-7.5C90.1 18 72.1 0 50 0zm0 66c-14 0-25.5-11.4-25.5-25.5S36 15.1 50 15.1s25.5 11.4 25.5 25.5S64 66 50 66z"></path></svg><svg data-name="Layer 1" id="plus" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><path d="M0 42h100v16H0z"></path><path d="M58 0v100H42V0z"></path></svg><svg id="search" viewbox="0 0 36.8 36.8" xmlns="http://www.w3.org/2000/svg"><path d="M14 28C6.3 28 0 21.7 0 14S6.3 0 14 0s14 6.3 14 14-6.3 14-14 14zm0-24C8.5 4 4 8.5 4 14s4.5 10 10 10 10-4.5 10-10S19.5 4 14 4zm20 32c-.5 0-1-.2-1.4-.6l-6-6c-.8-.8-.8-2 0-2.8s2-.8 2.8 0l6 6c.8.8.8 2 0 2.8-.4.4-.9.6-1.4.6z"></path></svg><svg data-name="Layer 1" id="social-facebook" viewbox="0 0 36.65 79" xmlns="http://www.w3.org/2000/svg"><path d="M8.14 39.5V79h16.35V39.5h8.77a2.39 2.39 0 002.37-2.13l.87-8.85a2.35 2.35 0 00-2.37-2.61h-9.72v-6.79a16.69 16.69 0 01.16-2.37 4.78 4.78 0 01.63-1.66A2.34 2.34 0 0126.86 14a10.57 10.57 0 013-.32h6.79V0H25.83C19.51 0 15 1.5 12.24 4.5s-4.1 7.43-4.1 13.2v8.22H2.37A2.38 2.38 0 000 28.28v8.85a2.38 2.38 0 002.37 2.37h5.77z"></path></svg><svg data-name="Layer 1" id="social-instagram" viewbox="0 0 64.48 64.48" xmlns="http://www.w3.org/2000/svg"><path d="M59.91 0H4.77A4.76 4.76 0 000 4.75v54.96a4.76 4.76 0 004.75 4.77h55a4.76 4.76 0 004.77-4.75V4.58A4.6 4.6 0 0059.91 0zM58 54.23a3.81 3.81 0 01-3.8 3.8h-44a3.81 3.81 0 01-3.8-3.8v-44a3.81 3.81 0 013.8-3.8h44.16A3.68 3.68 0 0158 10.12z"></path><path d="M32.24 16.12a16.12 16.12 0 1016.12 16.12 16.12 16.12 0 00-16.12-16.12zm0 26.12a10 10 0 11.06 0z"></path><circle cx="49.33" cy="15.8" r="4.19"></circle></svg><svg data-name="Layer 1" id="social-link" viewbox="0 0 100 100" xmlns="http://www.w3.org/2000/svg"><defs><style>.lcls-1{stroke:#000;stroke-miterlimit:10}</style></defs><path class="lcls-1" d="M44.24 92.52a26.07 26.07 0 01-36.79 0 26 26 0 01.07-36.76L31.29 32a26 26 0 0136.61-.07 6.47 6.47 0 01-9.16 9.14l.1.1a13 13 0 00-18.49-.12L16.63 64.91a13.05 13.05 0 0018.46 18.46l3.18-3.18A32.22 32.22 0 0050 82.37a33.46 33.46 0 004.7-.33z"></path><path class="lcls-1" d="M92.22 44.53l-23.8 23.81a26 26 0 01-36.61.07 6.47 6.47 0 019.09-9.21l-.1-.1a13 13 0 0018.49.12l23.78-23.84a13.05 13.05 0 00-18.45-18.45l-3.18 3.18a32.23 32.23 0 00-11.74-2.19 33.44 33.44 0 ...
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><defs><svg id="logo" viewbox="0 0 303.8 36" xmlns="http://www.w3.org/2000/svg"><path d="M6.4 28.7v2.4H14l1-2.4zm0 4.9V36h5.4l1.1-2.4zm19.5 0L27 36h5.3v-2.4zm6.4-4.9v2.4h-7.5l-1-2.4zM16 33.6L15 36h8.8l-1-2.4zm1.9-4.9l-1 2.4h5l-1-2.4zm15-2.6c2.9-2.8 5.9-5.2 5.9-8.7 0-3.6-3.1-5.8-7-4.8.6.6 1.1 1.3 1.3 2.1 1.3-.4 2.6.4 3 1.7.1.3.1.6.1.9 0 2.3-1.9 4.3-4.3 6.6h-3.6c1.8-2 3.5-4.1 3.5-6.9 0-5.1-6-7-9.8-4.3V15c2.7-2.1 7.2-1.5 7.2 2.1 0 2.3-1.8 4.4-4 6.8h-4.7V11.4c-.8-.4-1.7-.4-2.4 0v12.5h-4.5c-2.2-2.4-4-4.5-4-6.8 0-3.6 4.5-4.3 7.2-2.1v-2.3c-3.6-2.7-9.7-.8-9.7 4.3 0 2.8 1.6 4.9 3.5 6.9H6.9c-2.4-2.3-4.3-4.4-4.3-6.6-.1-1.3.9-2.5 2.2-2.6.3 0 .6 0 .9.1.2-.8.7-1.6 1.3-2.1-3.9-1-7 1.2-7 4.8 0 3.4 3 5.9 5.9 8.7h27zM19.4 7.7c.8-.1 1.5.5 1.6 1.3v.4c.6.2 1.1.6 1.5 1 .2-.5.3-1 .4-1.5 0-1.5-1.1-2.8-2.6-3V3.7H22V2h-1.7V0h-1.8v2h-1.7v1.6h1.7v2.1c-1.5.2-2.6 1.5-2.6 3 0 .5.1 1 .4 1.5.4-.4.9-.8 1.5-1V9c0-.8.7-1.5 1.5-1.4 0 .1.1.1.1.1zM53.2 16v20h7.1c3.8 0 6.5-2.4 6.5-6 0-2.9-1.8-4.2-3.8-5 1.4-.8 2.2-2.3 2.2-3.9 0-3-2.5-5.2-5.9-5.2l-6.1.1zm6.9 11.2c1.6-.1 3 1.1 3.1 2.7s-1.1 3-2.7 3.1h-3.9v-5.8h3.5zM58.8 19c1.4-.2 2.7.9 2.9 2.3.2 1.4-.9 2.7-2.3 2.9h-2.6V19h2zm29.4 17H92l-9.2-20h-3.4l-9.2 20H74l2.2-5H86l2.2 5zm-3.5-8h-7.2l3.6-8 3.6 8zm11.7-12v20h3.5V22l11 14.1h3.3V16h-3.5v14l-11-14zm36.2 17h-6.8v-5.8h6.8v-3h-6.8V19h6.8v-3h-10.4v20h10.4zm7.9 3.1h7.4c5.5 0 10-4.5 10-10s-4.5-10-10-10h-7.4v20zm7.4-17c3.9 0 7 3.1 7 7s-3.1 7-7 7H144V19l3.9.1zm31.9 17h3.8l-9.2-20H171l-9.2 20h3.8l2.2-5h9.9l2.1 5zm-3.6-8H169l3.6-8.1 3.6 8.1zm12.4-12v20h3.6V22l11 14.1h3.3V16h-3.6v14l-11-14zm36.9 13.8l6.2-8.1v14.3h3.5V16h-3.3l-7 9.3-7.1-9.3h-3.3v20h3.5V21.9l6.2 8zm33.6 6.2h3.8l-9.2-20h-3.4l-9.2 20h3.8l2.2-5h9.9l2.1 5zm-3.6-8h-7.2l3.6-8.1 3.6 8.1zm16.1 8v-8.9h.3l5.7 8.9h4.1l-6-9.1c2.6-.4 4.6-2.7 4.6-5.4 0-3.4-2.7-5.5-6.2-5.5h-6v20h3.5zm2.3-17c1.5-.1 2.7 1 2.9 2.5v.1c0 1.6-1.3 2.9-2.8 2.9h-2.4V19l2.3.1zm20.9 6.5l8.7-9.6h-4l-8.1 8.9V16h-3.5v20h3.5v-9.3l8.1 9.4h4.3z"></path></svg><svg id="logomark" viewbox="0 0 38.8 36" xmlns="http://www.w3.org/2000/svg"><path d="M6.4 28.7v2.4H14l1-2.4zm0 4.9V36h5.4l1.1-2.4zm19.5 0L27 36h5.3v-2.4zm6.4-4.9v2.4h-7.5l-1-2.4zM16 33.6L15 36h8.8l-1-2.4zm1.9-4.9l-1 2.4h5l-1-2.4zm15-2.6c2.9-2.8 5.9-5.2 5.9-8.7 0-3.6-3.1-5.8-7-4.8.6.6 1.1 1.3 1.3 2.1 1.3-.4 2.6.4 3 1.7.1.3.1.6.1.9 0 2.3-1.9 4.3-4.3 6.6h-3.6c1.8-2 3.5-4.1 3.5-6.9 0-5.1-6-7-9.8-4.3V15c2.7-2.1 7.2-1.5 7.2 2.1 0 2.3-1.8 4.4-4 6.8h-4.7V11.4c-.8-.4-1.7-.4-2.4 0v12.5h-4.5c-2.2-2.4-4-4.5-4-6.8 0-3.6 4.5-4.3 7.2-2.1v-2.3c-3.6-2.7-9.7-.8-9.7 4.3 0 2.8 1.6 4.9 3.5 6.9H6.9c-2.4-2.3-4.3-4.4-4.3-6.6-.1-1.3.9-2.5 2.2-2.6.3 0 .6 0 .9.1.2-.8.7-1.6 1.3-2.1-3.9-1-7 1.2-7 4.8 0 3.4 3 5.9 5.9 8.7h27v-.1zM19.4 7.7c.8-.1 1.5.5 1.6 1.3v.4c.6.2 1.1.6 1.5 1 .2-.5.3-1 .4-1.5 0-1.5-1.1-2.8-2.6-3V3.7H22V2h-1.7V0h-1.8v2h-1.7v1.6h1.7v2.1c-1.5.2-2.6 1.5-2.6 3 0 .5.1 1 .4 1.5.4-.4.9-.8 1.5-1V9c0-.8.7-1.5 1.5-1.4 0 .1.1.1.1.1z"></path></svg></defs></svg>
# </div>
# <header class="site__header header header--theme-one js-header" data-component="header">
# <div class="header__container">
# <div class="header__identity">
# <h6 class="site__outline-title header__title">
#           Banedanmark
#         </h6>
# <div class="header__logo">
# <div class="site__logo logo">
# <a class="logo__link" href="/" title="Til forsiden">
# <svg class="logo__svg" preserveaspectratio="xMinYMin meet">
# <use class="logo__asset" xlink:href="#logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <div class="header__navigation js-header-navigation">
# <div class="header__navigation-toggle toggle toggle--theme-one">
# <input class="toggle__control" id="toggle_{1}" type="checkbox"/>
# <label class="toggle__label js-header-toggle" for="toggle_{1}">
# <span class="toggle__indicator">
# <svg class="icon" viewbox="0 0 50 50">
# <rect class="toggle__line" height="7" width="50"></rect>
# <rect class="toggle__line" height="7" width="50" y="15"></rect>
# <rect class="toggle__line" height="7" width="30" x="21" y="30"></rect>
# <rect class="toggle__line toggle__line--animate" height="7" width="21" x="0" y="30"></rect>
# </svg>
# </span>
# </label>
# <div class="toggle__link toggle__link--bar">
# <a class="toggle__link-element" href="/da/Om-Banedanmark/Saadan-koerer-togene/Fjernbanen-2021">
#               Fjernbanen 2021
#             </a>
# </div>
# <div class="toggle__search">
# <a aria-label="Søg" class="toggle__search-anchor" href="/da/Soeg">
# <span class="icon">
# <svg class="icon__asset icon__asset--search">
# <use xlink:href="#search"></use>
# </svg>
# </span>
# </a>
# </div>
# <nav class="navigation navigation--main" role="navigation">
# <h6 class="site__outline-title">
#               Navigation
#             </h6>
# <div class="navigation__identity">
# <div class="navigation__logo">
# <div class="site__logo logo">
# <a class="logo__link" href="/" title="Til forsiden">
# <svg class="logo__svg" preserveaspectratio="xMinYMin meet">
# <use class="logo__asset" xlink:href="#logo" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </div>
# </div>
# </div>
# <nav aria-label="Primary" class="navigation navigation--principal" id="nav_main_principal" role="navigation">
# <h6 class="site__outline-title">
# 		Principal Navigation
# 	</h6>
# <ul class="navigation__section navigation__section--level-0 navigation__section--theme-one">
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{340BB1EA-C21D-4913-8566-6A7530CCF87E}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{340BB1EA-C21D-4913-8566-6A7530CCF87E}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link navigation__link--bar" href="/da/Borger">
# 						Borger
# 					</a>
# <ul class="navigation__section navigation__section--level-1">
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{F8801758-6963-4C07-BE60-F3F7F12B2F10}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{F8801758-6963-4C07-BE60-F3F7F12B2F10}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter">
# 			Baneprojekter
# 		</a>
# <ul class="navigation__section navigation__section--level-2">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Naer-dig">
# 			Baneprojekter nær dig
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{1FB08B6E-F742-4A50-A342-4DD4BD97D242}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{1FB08B6E-F742-4A50-A342-4DD4BD97D242}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet">
# 			Elektrificeringsprogrammet
# 		</a>
# <ul class="navigation__section navigation__section--level-3">
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{43C6A56F-3008-4510-9CD5-B469C30D633E}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{43C6A56F-3008-4510-9CD5-B469C30D633E}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Om-elektrificering">
# 			Om elektrificering
# 		</a>
# <ul class="navigation__section navigation__section--level-4">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Om-elektrificering/Hvorfor-elektrificerer-vi">
# 			Hvorfor elektrificerer vi
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Om-elektrificering/Beskaering-af-bevoksning">
# 			Beskæring af bevoksning
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Om-elektrificering/For-taet-paa-koereledningerne">
# 			For tæt på køreledningerne
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{FF4B1896-458B-45D1-87AC-46A40704FA7B}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{FF4B1896-458B-45D1-87AC-46A40704FA7B}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer">
# 			Strækninger vi elektrificerer
# 		</a>
# <ul class="navigation__section navigation__section--level-4">
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{E32C2A3D-3E61-4E84-BA23-39C384CE7CDE}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{E32C2A3D-3E61-4E84-BA23-39C384CE7CDE}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg">
# 			Elektrificering Roskilde-Kalundborg
# 		</a>
# <ul class="navigation__section navigation__section--level-5">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Besigtigelsesforretninger">
# 			Besigtigelsesforretninger
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Broer-Roskilde-_-Holbaek">
# 			Broer Roskilde - Holbæk
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{0B303848-26FA-44E5-98ED-C53ABF7AB86D}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{0B303848-26FA-44E5-98ED-C53ABF7AB86D}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet">
# 			Nyt fra projektet
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Banedanmark-river-to-broer-i-Holbaek-ned">
# 			Banedanmark river to broer i Holbæk ned
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Elektrificering-af-banen-mellem-Roskilde-og-Holbaek">
# 			Elektrificering af banen mellem Roskilde og Holbæk
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Kom-til-info_moede">
# 			Kom til info-møde
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Test-af-el_tog">
# 			Test af el-tog
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Test-af-koereledningsanlaeg-gennemfoert">
# 			Test af køreledningsanlæg gennemført
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Nyt-fra-projektet/Vi-elektrificerer-mellem-Roskilde-og-Holbaek">
# 			Vi elektrificerer mellem Roskilde og Holbæk
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Publikationer">
# 			Publikationer
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Servitut-om-eldrift">
# 			Servitut om eldrift
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Tidsplan">
# 			Tidsplan
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{2F68A094-D628-4C0F-B0A0-7E06CFC3EEE0}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{2F68A094-D628-4C0F-B0A0-7E06CFC3EEE0}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Om-projektet">
# 			Om projektet
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Om-projektet/Broer">
# 			Broer
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Om-projektet/Hoeringsproces-Ro_Kb">
# 			Høringsproces
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-Roskilde_Kalundborg/Om-projektet/VVM_redegoerelse">
# 			VVM-redegørelse
# 		</a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{70907AE9-C61E-460B-8370-D892A4E423BD}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{70907AE9-C61E-460B-8370-D892A4E423BD}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Stroem-til-fremtidens-tog">
# 			Strøm til fremtidens tog
# 		</a>
# <ul class="navigation__section navigation__section--level-5">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Stroem-til-fremtidens-tog/Fordelingsstation-Vasbygade">
# 			Fordelingsstation Vasbygade
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Vordingborg_Nykoebing-F">
# 			Vordingborg-Nykøbing F
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{5725AC7C-B18A-42DE-9EE6-BACD30609090}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{5725AC7C-B18A-42DE-9EE6-BACD30609090}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn">
# 			Elektrificering mellem Aarhus, Aalborg og Aalborg Lufthavn
# 		</a>
# <ul class="navigation__section navigation__section--level-5">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Om-projektet">
# 			Om projektet
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Besigtigelsesforretninger">
# 			Besigtigelsesmøder
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{A3ACA187-5939-4747-9030-CF2CC19BEB6C}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{A3ACA187-5939-4747-9030-CF2CC19BEB6C}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder">
# 			Nyheder
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/AAben-skurvogn-i-foraaret">
# 			Åben skurvogn i foråret
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/AAben-skurvogn-ved-Fjordvang">
# 			Åben skurvogn ved Fjordvang
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Banedanmark-ombygger-to-broer-i-Randers-i-2018">
# 			Banedanmark ombygger to broer i Randers i 2018
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Banedanmark-udfoerer-asfaltarbejder-paa-Parkboulevarden-og-Viborgvej">
# 			Banedanmark udfører asfaltarbejder på Parkboulevarden og Viborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Banedanmarks-arbejde-ved-Viborgvej-i-Paasken">
# 			Banedanmarks arbejde ved Viborgvej i Påsken
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Broarbejde-i-Randers-frem-mod-paasken">
# 			Broarbejde i Randers frem mod påsken
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Broarbejde-ved-Fjordvang">
# 			Broarbejde ved Fjordvang
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Fjernelse-af-gamle-fundamenter-ved-Fjordvang">
# 			Fjernelse af gamle fundamenter ved Fjordvang
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Foerste-aaben-skurvogn-i-2020">
# 			Første åben skurvogn i 2020
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Gangbro-ved-Fjordvang-er-forsinket">
# 			Gangbro ved Fjordvang er forsinket
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Kom-til-AAben-Skurvogn">
# 			Kom til Åben Skurvogn
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Kom-til-infomoede-om-store-jernbaneprojekter-i-Favrskov">
# 			Kom til infomøde om store jernbaneprojekter i Favrskov
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Moed-os-til-AAben-Skurvogn">
# 			Mød os til Åben Skurvogn
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Nu-begynder-arbejdet-med-at-udskifte-broen_-der-foerer-Viborgvej-over-banen">
# 			Nu begynder arbejdet med at udskifte broen, der fører Viborgvej over banen
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Nu-begynder-vores-arbejde-ved-OErrildvej">
# 			Nu begynder vores arbejde ved Ørrildvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Nu-gaar-arbejdet-paa-Poppelvaenget-i-gang">
# 			Nu går arbejdet på Poppelvænget i gang
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Ny-bro-over-banen-i-Randers">
# 			Ny bro over banen i Randers
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Nyhedsside">
# 			Nyhedsside
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Omlaegning-af-Viborgvej">
# 			Omlægning af Viborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Ramning-og-vibrering-er-nu-overstaaet">
# 			Ramning og vibrering er nu overstået
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Saa-ruller-trafikken-igen-paa-Viborgvej">
# 			Så ruller trafikken igen på Viborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Sommerens-arbejder">
# 			Sommerens arbejder
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Spaerring-af-Viborgvej">
# 			Spærring af Viborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Stoejende-arbejder-ved-Hvidemoellevej">
# 			Støjende arbejder ved Hvidemøllevej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Vesterlandsvej-forventes-aabnet-i-april">
# 			Vesterlandsvej forventes åbnet i april
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Viborgvej-lukket-i-nogle-faa-dage">
# 			Viborgvej lukket i nogle få dage
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nyheder/Vibrering-og-ramning-af-spuns-ved-Viborgvej">
# 			Vibrering og ramning af spuns ved Viborgvej
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{F1D971C0-597C-4FF0-BDC7-6E791A76594C}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{F1D971C0-597C-4FF0-BDC7-6E791A76594C}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer">
# 			Broer
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Baekkedalsvej">
# 			Bækkedalsvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Gammel-Viborgvej">
# 			Gammel Viborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Hvidemoellevej">
# 			Hvidemøllevej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Klaestrupholmvej">
# 			Klæstrupholmvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Kollerupvej">
# 			Kollerupvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Langaa-Station">
# 			Langå Station
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Mariedal">
# 			Mariedal
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Moellegaardsvej">
# 			Møllegårdsvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Over-Kaeret">
# 			Over Kæret
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Poppelvaenget">
# 			Poppelvænget
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Raakildevej">
# 			Råkildevej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Selkaervej">
# 			Selkærvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Silkeborgvej">
# 			Silkeborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Skanderborgvej-i-Hadsten">
# 			Skanderborgvej i Hadsten
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Stenstrupvej">
# 			Stenstrupvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Stoevring-Station">
# 			Støvring Station
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Svenstrup-Station">
# 			Svenstrup Station
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Vaethvej">
# 			Væthvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Vaseholm">
# 			Vaseholm
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Vester-Alle">
# 			Vester Allé
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Broer/Vesterbro">
# 			Vesterbro
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Miljoeredegoerelse">
# 			Miljøredegørelse
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Aarhus_Aalborg_Aalborg-Lufthavn/Nabo-til-arbejdet">
# 			Nabo til arbejdet
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{AA72EA6F-38FD-4121-87CF-D2A209EC4357}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{AA72EA6F-38FD-4121-87CF-D2A209EC4357}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus">
# 			Elektrificering Fredericia-Aarhus
# 		</a>
# <ul class="navigation__section navigation__section--level-5">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Besigtigelsesforretninger">
# 			Besigtigelsesforretninger
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{8D42ECC6-6EFC-4647-B4A9-87857ED4DCEB}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{8D42ECC6-6EFC-4647-B4A9-87857ED4DCEB}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet">
# 			Nyt om projektet
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Informationsmoeder-den-20_-og-21_-marts">
# 			Borgermøder den 20. og 21. marts
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Arbejder-ved-broen-over-banen-paa-Hovedvej-A10">
# 			Arbejder ved broen over banen på Hovedvej A10
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Besigtigelsesforretning-Fredericia_Aarhus">
# 			Besigtigelsesforretning Fredericia-Aarhus
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Besigtigelsesforretning-mellem-Fredericia-og-Vejle-i-februar">
# 			Besigtigelsesforretning mellem Fredericia og Vejle i februar
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Besigtigelsesforretning-mellem-Horsens-og-Hedensted">
# 			Besigtigelsesforretning mellem Horsens og Hedensted
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Broarbejde-ved-Skanderborgvej">
# 			Broarbejde ved Skanderborgvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Broarbejder-mellem-Fredericia-og-Aarhus">
# 			Broarbejder mellem Fredericia og Aarhus
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Informationsmoede-4_-april-2019">
# 			Informationsmøde 4. april 2019
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Informationsmoede-den-22_-november">
# 			Informationsmøde den 22. november
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Ingen-brohaevning-ved-Bygholm-Parkvej">
# 			Ingen brohævning ved Bygholm Parkvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Ingen-haevning-af-broen-over-Laasbyvej">
# 			Ingen hævning af broen over Låsbyvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Ingen-saenkning-af-sporet-ved-Bjarkesgade-i-Horsens">
# 			Ingen sænkning af sporet ved Bjarkesgade i Horsens
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Ingen-saenkning-af-sporet-ved-Juelsmindevej">
# 			Ingen sænkning af sporet ved Juelsmindevej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Kommissarius-holder-besigtigelsesforretninger-den-28_-og-29_-maj-mellem-Fredericia-og-Vejle">
# 			Kommissarius holder besigtigelsesforretninger den 28. og 29. maj mellem Fredericia og Vejle
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Ombygning-af-broer-i-Vejle-Kommune">
# 			Ombygning af broer i Vejle Kommune
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Proevegravninger-mellem-Fredericia-og-Hovedgaard">
# 			Prøvegravninger mellem Fredericia og Hovedgård
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Proevegravninger-mellem-Hovedgaard-og-Hoerning">
# 			Prøvegravninger mellem Hovedgård og Hørning
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Nyt-om-projektet/Toldbodvejbroen-haeves">
# 			Toldbodvejbroen hæves
# 		</a>
# </li>
# </ul>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Om-projektet">
# 			Om projektet
# 		</a>
# </li>
# <li class="navigation__item">
# <input class="navigation__control" id="nav_main_principal_node_{EE909A33-D134-4682-8B18-207383C05AD4}" type="checkbox"/>
# <label class="navigation__label" for="nav_main_principal_node_{EE909A33-D134-4682-8B18-207383C05AD4}">
# <span class="navigation__indicator">
# <svg class="icon">
# <use xlink:href="#arrow-small" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </label>
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer">
# 			Broer
# 		</a>
# <ul class="navigation__section navigation__section--level-6">
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer/Baastrupvej">
# 			Båstrupvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer/Bjertrupvej">
# 			Bjertrupvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer/Bleldvej">
# 			Bleldvej
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer/Boerkop-station">
# 			Børkop station
# 		</a>
# </li>
# <li class="navigation__item">
# <a class="navigation__link" href="/da/Borger/Baneprojekter/Elektrificeringsprogrammet/Straekninger-vi-elektrificerer/Elektrificering-_-Fredericia_Aarhus/Broer/Faarbjergvej">
# 			Fårbjergvej
# 		</a>
# </li>
# ...
# <time class="article__publishdate" data-component="reveal" datetime="2021-05-31T12:11:56">
# 				31.05.2021
# 			</time>
# </div>
# </header>
# <section class="section section--white section--reveal">
# <div class="section__inner content" data-component="reveal">
# <div class="row">
# <div class="col-sm-8">
# <div class="content__main">
# <p>Sådan opgør vi punktlighed i 2021<br/>
#  <br/>
# Vi måler på rettidige ankomster inden for 2:59 minutter og vægter i forhold til antal af passagerer. Det vil sige, at et tog i myldretiden med mange passagerer vægter mere end en afgang med færre passagerer i ydertimerne. Tog aflyst mindre end 72 timer før afgang tæller som forsinket.<br/>
# <br/>
# Der kører flere forskellige togselskaber på den statslige jernbane. Her på siden kan du se punktligheden for DSB, Arriva og Nordjyske Jernbaner.</p>
#
# <div>
# <table style="height: 108px; width: 961.6px;">
# <tbody>
# <tr>
# <td style="text-align: left;">Punktlighed<br/>
#             DSB 2021</td>
# <td style="text-align: left;">Kundepunktlighed DSB 2021<br/>
#             (mål 78,7 %)<br/>
# </td>
# <td style="text-align: left;">Banedanmarks ansvar<br/>
#             (Max. 9,0 %)</td>
# <td style="text-align: left;">Jernbanevirksomhedens ansvar</td>
# <td style="text-align: left;">Eksterne forhold</td>
# </tr>
# <tr>
# <td style="text-align: left;">januar</td>
# <td style="text-align: left;">88,5 %</td>
# <td style="text-align: left;">5,6 %</td>
# <td style="text-align: left;">3,5 %</td>
# <td style="text-align: left;"> 2,4 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">februar</td>
# <td style="text-align: left;">84,8 %</td>
# <td style="text-align: left;">7,6 %</td>
# <td style="text-align: left;">4,2 % </td>
# <td style="text-align: left;">3,4 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">marts</td>
# <td style="text-align: left;">87,4 % </td>
# <td style="text-align: left;">5,7 % </td>
# <td style="text-align: left;">4,0 % </td>
# <td style="text-align: left;">2,9 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">april</td>
# <td style="text-align: left;">82,9 % </td>
# <td style="text-align: left;">10,6 % </td>
# <td style="text-align: left;">3,9 % </td>
# <td style="text-align: left;">2,6 % </td>
# </tr>
# <tr>
# <td style="text-align: left;"> maj</td>
# <td style="text-align: left;">81,6 % </td>
# <td style="text-align: left;">9,2 % </td>
# <td style="text-align: left;">5,0 % </td>
# <td style="text-align: left;">4,2 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juni </td>
# <td style="text-align: left;">81,9 % </td>
# <td style="text-align: left;">7,9 % </td>
# <td style="text-align: left;">5,9 % </td>
# <td style="text-align: left;">4,3 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juli </td>
# <td style="text-align: left;">73,7 % </td>
# <td style="text-align: left;">12,8 % </td>
# <td style="text-align: left;">7,3 % </td>
# <td style="text-align: left;">6,2 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">august</td>
# <td style="text-align: left;"> 76,8 %</td>
# <td style="text-align: left;">76,8 % </td>
# <td style="text-align: left;">11,3 % </td>
# <td style="text-align: left;">6,5 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">september </td>
# <td style="text-align: left;"> 81,6 %</td>
# <td style="text-align: left;"> 8,2 %</td>
# <td style="text-align: left;">5,4 % </td>
# <td style="text-align: left;">4,8 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">oktober </td>
# <td style="text-align: left;"> 75,7 %</td>
# <td style="text-align: left;"> 11,0 %</td>
# <td style="text-align: left;">5,2 % </td>
# <td style="text-align: left;">8,1 % </td>
# </tr>
# </tbody>
# </table>
#  </div>
# <div>
# <table style="height: 134px; width: 957.6px;">
# <tbody>
# <tr>
# <td style="text-align: left;">Punktlighed<br/>
#             Arriva 2021</td>
# <td style="text-align: left;">Togpunktlighed Arriva 2021<br/>
# </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">Banedanmarks ansvar<br/>
#             (max. 4,5 %)</td>
# <td style="text-align: left;">Jernbanevirksomhedens ansvar</td>
# <td style="text-align: left;">Eksterne forhold</td>
# </tr>
# <tr>
# <td style="text-align: left;">januar</td>
# <td style="text-align: left;">94,2 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">3,2 %</td>
# <td style="text-align: left;">2,0 %</td>
# <td style="text-align: left;">0,8 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">februar</td>
# <td style="text-align: left;">88,2 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">7,1  %</td>
# <td style="text-align: left;">2,9 %</td>
# <td style="text-align: left;">1,8 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">marts</td>
# <td style="text-align: left;">93,2 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">3,5 %</td>
# <td style="text-align: left;">2,7 %</td>
# <td style="text-align: left;">0,6 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">april</td>
# <td style="text-align: left;">89,4 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">6,1 %</td>
# <td style="text-align: left;">3,9 %</td>
# <td style="text-align: left;">0,6 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">maj </td>
# <td style="text-align: left;">89,9 % </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">5,7 %</td>
# <td style="text-align: left;">3,6 % </td>
# <td style="text-align: left;">0,8 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juni </td>
# <td style="text-align: left;">86,6 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">7,4 % </td>
# <td style="text-align: left;">4,1 % </td>
# <td style="text-align: left;">1,9 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juli </td>
# <td style="text-align: left;">89,0 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">5,0 % </td>
# <td style="text-align: left;">5,0 % </td>
# <td style="text-align: left;">1,0 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">august </td>
# <td style="text-align: left;">90,4 % </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">3,1 % </td>
# <td style="text-align: left;">5,4 % </td>
# <td style="text-align: left;">3,1 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">september</td>
# <td style="text-align: left;">89,4 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">4,4 % </td>
# <td style="text-align: left;">5,1 % </td>
# <td style="text-align: left;">1,1 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">oktober </td>
# <td style="text-align: left;">88,6 %</td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;">5,2 % </td>
# <td style="text-align: left;">3,9 % </td>
# <td style="text-align: left;">2,3 % </td>
# </tr>
# </tbody>
# </table>
# </div>
# <div> </div>
# <div>
# <table style="width: 1156px;">
# <tbody>
# <tr>
# <td style="text-align: left;">Punktlighed<br/>
#             Nordjyske Jernbaner</td>
# <td style="text-align: left;">Togpunktlighed <br/>
#             Nordjyske Jernbaner 2021.<br/>
#             (Mål: 90,3 %)</td>
# <td style="text-align: left;">Banedanmarks ansvar<br/>
#             (Max. 5,5%)</td>
# <td style="text-align: left;">Jernbanevirksomhedens <br/>
#             ansvar</td>
# <td style="text-align: left;">Eksterne forhold</td>
# </tr>
# <tr>
# <td style="text-align: left;">januar</td>
# <td style="text-align: left;">97,2 %</td>
# <td style="text-align: left;">2,5 %</td>
# <td style="text-align: left;">0,3 %</td>
# <td style="text-align: left;">0,0 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">februar</td>
# <td style="text-align: left;">97,0 %</td>
# <td style="text-align: left;">1,6 %</td>
# <td style="text-align: left;">0,9 %</td>
# <td style="text-align: left;">0,4 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">marts</td>
# <td style="text-align: left;">96,9 %</td>
# <td style="text-align: left;">2,7 %</td>
# <td style="text-align: left;">0,2 %</td>
# <td style="text-align: left;">0,2 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">april<br/>
# </td>
# <td style="text-align: left;">96,4 %</td>
# <td style="text-align: left;">2,6 %</td>
# <td style="text-align: left;">0,8 %</td>
# <td style="text-align: left;">0,3 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">maj </td>
# <td style="text-align: left;"> 97,6 %</td>
# <td style="text-align: left;">1,6 %</td>
# <td style="text-align: left;">0,5 % </td>
# <td style="text-align: left;"> 0,3 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">juni </td>
# <td style="text-align: left;"> 96,9 %</td>
# <td style="text-align: left;">2,5 %</td>
# <td style="text-align: left;">0,4 % </td>
# <td style="text-align: left;">0,2 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juli </td>
# <td style="text-align: left;">95,2 % </td>
# <td style="text-align: left;">3,3 % </td>
# <td style="text-align: left;">1,0 % </td>
# <td style="text-align: left;">0,5 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">august </td>
# <td style="text-align: left;">96,2 % </td>
# <td style="text-align: left;"> 2,4 % </td>
# <td style="text-align: left;">0,9 % </td>
# <td style="text-align: left;">0,5 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">september </td>
# <td style="text-align: left;">95,7 % </td>
# <td style="text-align: left;">2,7 % </td>
# <td style="text-align: left;">0,8 % </td>
# <td style="text-align: left;">0,5 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">oktober</td>
# <td style="text-align: left;">93,9 % </td>
# <td style="text-align: left;">5,0 % </td>
# <td style="text-align: left;">0,8 % </td>
# <td style="text-align: left;">0,3 % </td>
# </tr>
# <tr>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# </tr>
# <tr>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# <td style="text-align: left;"> </td>
# </tr>
# </tbody>
# </table>
#  </div>
# </div>
# </div>
# <div class="col-sm-4">
# <aside class="content__aside">
# <h6 class="site__outline-title">
# </h6>
# </aside>
# </div>
# </div>
# </div>
# </section>
# </article>
# </main>
# <footer class="site__footer">
# <section class="section section--fullwidth section--black section--nomargin">
# <h6 class="site__outline-title">
# 			Footer
# 		</h6>
# <div class="section__inner footer">
# <section class="footer__column footer__column--last" itemscope="" itemtype="http://schema.org/GovernmentOffice">
# <div class="footer__section footer__section--top">
# <div class="footer__logo">
# <div class="site__logo logo logo--light">
# <a class="logo__link" href="/" title="Til forsiden">
# <svg class="logo__svg" preserveaspectratio="xMinYMin meet">
# <use class="logo__asset" xlink:href="#logomark" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# <link href="/dist/global/assets/gfx/logo.svg" itemprop="image"/>
# </a>
# </div>
# </div>
# <h2 class="hidden" itemprop="name">Banedanmark</h2>
# </div>
# <div class="footer__section footer__section--bottom footer__separator">
# <ul class="footer__list footer__company-info">
# <li class="footer__list-item">
# <div itemprop="address">Carsten Niebuhrs Gade 43<br/>
#     1577 København V</div>
# </li>
# <li class="footer__list-item">
# <div itemprop="telephone">8234 0000</div>
# </li>
# <li class="footer__list-item">
# <div itemprop="email"><a href="mailto:banedanmark@bane.dk?subject=Kontakt%20Banedanmark">banedanmark@bane.dk</a></div>
# </li>
# <li class="footer__list-item">
# <div itemprop="taxID">CVR 18632276</div>
# </li>
# <li class="footer__list-item">
# <div itemprop="taxID">EAN 5798 000 89 32 07</div>
# </li>
# </ul>
# </div>
# </section>
# <section class="footer__column">
# <div class="footer__section footer__section--top">
# <h2 class="section__title">Gå til</h2>
# <ul class="footer__list">
# <li class="footer__list-item"><a class="footer__link" href="/da/Borger">Borger</a></li>
# <li class="footer__list-item"><a class="footer__link" href="/da/Leverandoer">Leverandør</a></li>
# <li class="footer__list-item"><a class="footer__link" href="/da/Jernbanevirksomhed">Jernbanevirksomhed</a></li>
# </ul>
# </div>
# <div class="footer__section footer__section--bottom footer__separator">
# <ul class="footer__list">
# <li class="footer__list-item">
# <a class="footer__link" href="/da/Om-Banedanmark">Om Banedanmark</a>
# </li> <li class="footer__list-item">
# <a class="footer__link" href="/da/Presse">Presse</a>
# </li> <li class="footer__list-item">
# <a class="footer__link" href="/da/Job-og-karriere">Job</a>
# </li> <li class="footer__list-item">
# <a class="footer__link" href="/da/Kontakt">Kontakt</a>
# </li> <li class="footer__list-item">
# <a class="footer__link" href="https://uk.banedanmark.dk">English</a>
# </li> </ul>
# </div>
# </section>
# <section class="footer__column footer__column--double">
# <div class="footer__section footer__section--top footer__separator subscriptions" data-component="subscriptions" data-messages-email-format="Din e-mailadresse skal være i formatet navn@domæne.dk" data-messages-email-required="Vi skal bruge din e-mailadresse så vi kan føje dig til abonnementet">
# <div class="subscriptions__signup signup">
# <h2 class="section__title">
# 							Nyhedsbreve
# 						</h2>
# <div class="footer__subsection footer__subsection--first">
# <p>Tilmeld dig et af vores nyhedsbreve med seneste nyt om Banedanmark og vores projekter.
# <br/>
# <a class="spot__button button button--light button--small button--interactive-hard" href="~/link.aspx?_id=CE19BC1FB0F34A2F9A6F93C1908A1210&amp;_z=z"><span style="color: #000000;">Tilmeld nyhedsbrev</span></a></p>
# </div>
# </div>
# </div>
# <div class="footer__section footer__section--bottom footer__section--flex">
# <div class="footer__subsection">
# <h2 class="section__title">banedanmark.dk</h2>
# <ul class="footer__list">
# <li class="footer__list-item">
# <a class="footer__link" href="/da/Privatliv">Persondatapolitik</a>
# </li> <li class="footer__list-item">
# <a class="footer__link" href="/da/Privatlivspolitik">Cookies &amp; Apps</a>
# </li> </ul>
# </div>
# <div class="footer__subsection footer__subsection--first">
# <h2 class="section__title">Følg med</h2>
# <p>Klik på ikonerne herunder, og følg os på de sociale medier</p>
# </div>
# <div class="footer__social">
# <ul class="social-sharing social-sharing--invert social-sharing--centered social-sharing--spacious">
# <li class="social-sharing__listitem">
# <a href="https://www.facebook.com/banedanmark/" target="_blank" title="Banedanmark på Facebook">
# <span class="icon icon--light icon--circle icon--interactive-hard">
# <svg class="icon__asset icon__asset--social-facebook">
# <use xlink:href="#social-facebook" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="social-sharing__listitem">
# <a href="https://www.instagram.com/banedanmark/?hl=da" target="_blank" title="Banedanmark på Instagram">
# <span class="icon icon--light icon--circle icon--interactive-hard">
# <svg class="icon__asset icon__asset--social-instagram">
# <use xlink:href="#social-instagram" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="social-sharing__listitem">
# <a href="https://dk.linkedin.com/company/banedanmark" target="_blank" title="Banedanmark på LinkedIn">
# <span class="icon icon--light icon--circle icon--interactive-hard">
# <svg class="icon__asset icon__asset--social-linkedin">
# <use xlink:href="#social-linkedin" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="social-sharing__listitem">
# <a href="https://twitter.com/banedanmark" target="_blank" title="Banedanmark på Twitter">
# <span class="icon icon--light icon--circle icon--interactive-hard">
# <svg class="icon__asset icon__asset--social-twitter">
# <use xlink:href="#social-twitter" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# <li class="social-sharing__listitem">
# <a href="https://www.youtube.com/user/Banedanmark" target="_blank" title="Banedanmark på Youtube">
# <span class="icon icon--light icon--circle icon--interactive-hard">
# <svg class="icon__asset icon__asset--social-youtube">
# <use xlink:href="#social-youtube" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </section>
# </div>
# </section>
# </footer>
# <script src="/-/design/dist/global/scripts/app---a42d741d.js"></script>
# </body>
# </html>

# %% [markdown]
# Sektionen der indeholder den tabel med den ønskede data kan nu lokaliseres:

# %%
table_sections = soup.find_all('table')

# eksempel på tabel:
table_sections[0]
# Out:
# <table style="height: 108px; width: 961.6px;">
# <tbody>
# <tr>
# <td style="text-align: left;">Punktlighed<br/>
#             DSB 2021</td>
# <td style="text-align: left;">Kundepunktlighed DSB 2021<br/>
#             (mål 78,7 %)<br/>
# </td>
# <td style="text-align: left;">Banedanmarks ansvar<br/>
#             (Max. 9,0 %)</td>
# <td style="text-align: left;">Jernbanevirksomhedens ansvar</td>
# <td style="text-align: left;">Eksterne forhold</td>
# </tr>
# <tr>
# <td style="text-align: left;">januar</td>
# <td style="text-align: left;">88,5 %</td>
# <td style="text-align: left;">5,6 %</td>
# <td style="text-align: left;">3,5 %</td>
# <td style="text-align: left;"> 2,4 %</td>
# </tr>
# <tr>
# <td style="text-align: left;">februar</td>
# <td style="text-align: left;">84,8 %</td>
# <td style="text-align: left;">7,6 %</td>
# <td style="text-align: left;">4,2 % </td>
# <td style="text-align: left;">3,4 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">marts</td>
# <td style="text-align: left;">87,4 % </td>
# <td style="text-align: left;">5,7 % </td>
# <td style="text-align: left;">4,0 % </td>
# <td style="text-align: left;">2,9 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">april</td>
# <td style="text-align: left;">82,9 % </td>
# <td style="text-align: left;">10,6 % </td>
# <td style="text-align: left;">3,9 % </td>
# <td style="text-align: left;">2,6 % </td>
# </tr>
# <tr>
# <td style="text-align: left;"> maj</td>
# <td style="text-align: left;">81,6 % </td>
# <td style="text-align: left;">9,2 % </td>
# <td style="text-align: left;">5,0 % </td>
# <td style="text-align: left;">4,2 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juni </td>
# <td style="text-align: left;">81,9 % </td>
# <td style="text-align: left;">7,9 % </td>
# <td style="text-align: left;">5,9 % </td>
# <td style="text-align: left;">4,3 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">juli </td>
# <td style="text-align: left;">73,7 % </td>
# <td style="text-align: left;">12,8 % </td>
# <td style="text-align: left;">7,3 % </td>
# <td style="text-align: left;">6,2 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">august</td>
# <td style="text-align: left;"> 76,8 %</td>
# <td style="text-align: left;">76,8 % </td>
# <td style="text-align: left;">11,3 % </td>
# <td style="text-align: left;">6,5 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">september </td>
# <td style="text-align: left;"> 81,6 %</td>
# <td style="text-align: left;"> 8,2 %</td>
# <td style="text-align: left;">5,4 % </td>
# <td style="text-align: left;">4,8 % </td>
# </tr>
# <tr>
# <td style="text-align: left;">oktober </td>
# <td style="text-align: left;"> 75,7 %</td>
# <td style="text-align: left;"> 11,0 %</td>
# <td style="text-align: left;">5,2 % </td>
# <td style="text-align: left;">8,1 % </td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# Da det kun er øveste tabel der indeholder data med DSB, ses der bort fra de øvrige.
#
# Hver række i tabellen kan nu lokeres:

# %%
bane_rows = table_sections[0].find_all('tr')

# eksempel inspiceres:
bane_rows[1]
# Out:
# <tr>
# <td style="text-align: left;">januar</td>
# <td style="text-align: left;">88,5 %</td>
# <td style="text-align: left;">5,6 %</td>
# <td style="text-align: left;">3,5 %</td>
# <td style="text-align: left;"> 2,4 %</td>
# </tr>

# %% [markdown]
# Den første række indeholder overskrifter til kolonner, og kan derfra springes over, når data hentes.
#
# Den ønskede data kan nu hentes ud. Eksempel følger:

# %%
ex_data = bane_rows[1].find_all('td')

print('Måned: ' + ex_data[0].text)
print('Punktlighed: ' + ex_data[1].text)
print('Banedanmarks ansvar: ' + ex_data[2].text)
print('DSB\'s ansvar: ' + ex_data [3].text)
print('Eksterne forhold: ' + ex_data[4].text)
# Out:
# Måned: januar
# Punktlighed: 88,5 %
# Banedanmarks ansvar: 5,6 %
# DSB's ansvar: 3,5 %
# Eksterne forhold:  2,4 %

# %% [markdown]
# ### Eksport til dataframe
# Ovenstående gennemgang gør det nu muligt, at eksportere til et dataframe.
#
# Til det formel oprettes et loop, der henter data fra hvert år (som har en unik url).
#
# Den data der ønskes udtrækket, er følgende:
# - Årstal
# - Måned
# - Punktlighed
# - Banedanmarks ansvar
# - DSB's ansvar
# - Eksterne forhold

# %%
#initiér tid til debug
start_time = time.time()

#en tom liste oprettes for hvert af de ønskede data, der hver skal have sin egen kolonne i dataframet
year = []
month = []
punktlighed = []
banedk_a = []
dsb_a = []
ekstern_a = []

# en liste over de år, der skal indhentes data fra:
year_list = [2016, 2017, 2018, 2019, 2020, 2021]

# et loop startes for hvert år
for i in range(len(year_list)):
    # årstallet gemmes
    this_year = year_list[i]
    
    # url til data, hvor årstal ændres:
    url = 'https://www.bane.dk/da/Om-Banedanmark/Saadan-koerer-togene/Fjernbanen-' + str(this_year)
    
    # BeautifulSoup objekt af siden gemmes:
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # tabellen med den ønskede data lokaliseres:
    table = soup.find('table')
    
    # en liste over data rækkerne kan nu findes:
    table_rows = table.find_all('tr')
    
    # hver række kan nu loopes igennem, hvor første springes over:
    for j in range(len(table_rows)-1):
        # en liste over den ønskede data i den pågælde række kan nu hentes:
        data_list = table_rows[j+1].find_all('td')
        
        # data kan nu hentes til listen
        year.append(this_year)
        month.append(data_list[0].text)
        punktlighed.append(data_list[1].text)
        banedk_a.append(data_list[2].text)
        dsb_a.append(data_list[3].text)
        ekstern_a.append(data_list[4].text)
    

# DataFramet kan nu konstrueres:
df_ansvar = pd.DataFrame({'Årstal':year,
                          'Måned':month,
                          'Punktlighed':punktlighed,
                          'Banedanmarks ansvar':banedk_a,
                          'DSB\'s ansvar':dsb_a,
                          'Eksterne forhold':ekstern_a})

#tid printes
print("--- %s seconds ---" % round((time.time() - start_time),2))
# Out:
# --- 7.01 seconds ---

# %% [markdown]
# Dataframet er konstrueret, og kan nu inspiceres:

# %%
df_ansvar
# Out:
#     Årstal       Måned Punktlighed Banedanmarks ansvar DSB's ansvar  \
# 0     2016      januar      75,5 %              10,6 %       10,6 %
# 1     2016     februar      80,2 %               7,0 %        9,1 %
# 2     2016       marts      73,6 %              13,2 %        9,2 %
# 3     2016       april      73,5 %              10,9 %       10,9 %
# 4     2016         maj      65,6 %              18,8 %       10,2 %
# ..     ...         ...         ...                 ...          ...
# 65    2021       juni      81,9 %               7,9 %        5,9 %
# 66    2021       juli      73,7 %              12,8 %        7,3 %
# 67    2021      august      76,8 %             76,8 %       11,3 %
# 68    2021  september       81,6 %               8,2 %       5,4 %
# 69    2021    oktober       75,7 %              11,0 %       5,2 %
#
#    Eksterne forhold
# 0             3,3 %
# 1             3,8 %
# 2             4,0 %
# 3             4,7 %
# 4             5,4 %
# ..              ...
# 65           4,3 %
# 66           6,2 %
# 67           6,5 %
# 68           4,8 %
# 69           8,1 %
#
# [70 rows x 6 columns]

# %% [markdown]
# ### Omkodning af procent
# Rækkerne med procent omkodes til float, så der kan regnes på procenterne.

# %%
# Liste over kolonnenavne
omkod_list = ["Punktlighed", "Banedanmarks ansvar", "DSB\'s ansvar", "Eksterne forhold"]

#df_test = df_punktlighed.copy()

# Hver kolonne loopes igennem og omkodes til float:
for i in range(len(omkod_list)):
    df_ansvar[omkod_list[i]] = df_ansvar[omkod_list[i]].\
                                                        str.\
                                                        replace('&nbsp;', '').\
                                                        str.\
                                                        replace('\xa0', '').\
                                                        str.\
                                                        rstrip('%').\
                                                        str.\
                                                        replace(',', '.').\
                                                        astype('float') / 100.0

df_ansvar
# Out:
#     Årstal       Måned  Punktlighed  Banedanmarks ansvar  DSB's ansvar  \
# 0     2016      januar        0.755                0.106         0.106
# 1     2016     februar        0.802                0.070         0.091
# 2     2016       marts        0.736                0.132         0.092
# 3     2016       april        0.735                0.109         0.109
# 4     2016         maj        0.656                0.188         0.102
# ..     ...         ...          ...                  ...           ...
# 65    2021       juni         0.819                0.079         0.059
# 66    2021       juli         0.737                0.128         0.073
# 67    2021      august        0.768                0.768         0.113
# 68    2021  september         0.816                0.082         0.054
# 69    2021    oktober         0.757                0.110         0.052
#
#     Eksterne forhold
# 0              0.033
# 1              0.038
# 2              0.040
# 3              0.047
# 4              0.054
# ..               ...
# 65             0.043
# 66             0.062
# 67             0.065
# 68             0.048
# 69             0.081
#
# [70 rows x 6 columns]

# %% [markdown]
# ### Sammenligning af ansvar på tværs af år
# Sammenliging af den gennemsnittelig procent for ansvar på tværs af årene:

# %%
split_vars = ['Årstal'] 
apply_vars = ['Banedanmarks ansvar', 'DSB\'s ansvar', 'Eksterne forhold']
apply_fcts = ['mean']

df_illu = df_ansvar.groupby(split_vars)[apply_vars].agg(apply_fcts)

x_labels = df_illu.index.get_level_values(0)
l_banedk = list(df_illu['Banedanmarks ansvar']['mean'])
l_dsb = list(df_illu['DSB\'s ansvar']['mean'])
l_ekstern = list(df_illu['Eksterne forhold']['mean'])

values1 = np.array(l_banedk)
values2 = np.array(l_dsb)
values3 = np.array(l_ekstern)
x = np.arange(len(x_labels))

width = 0.25

# plot
fig, ax = plt.subplots(figsize=(15,7))
rects1 = ax.bar(x-width, values1, width, label='Banedanmark')
rects2 = ax.bar(x, values2, width, label='DSB')
rects3 = ax.bar(x+width, values3, width, label='Eksterne forhold')

# funktion der tilføjer tekst med procent over søjlerne i diagrammet
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
        
# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           fontsize='16', \
           horizontalalignment='center', \
           verticalalignment='top')

# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj grid
plt.grid(axis = 'y')

# tilføj titel
ax.set_title('Ansvar for forsinkelser på fjerntog (%)', \
             fontweight='bold', \
             fontsize='16')

# tilføj legend
plt.legend(loc="upper left", prop={'size': 16})

# %% [markdown]
# ## Togpunktlighed: Københavns Hovedbanegård
# Banedanmark har udleveret data over togpunktligheden på Københavns Hovedbangård i perioden 2015-2019. Disse importeres:

# %%
#datasættet importeres fra excel fil
df_kbh = pd.read_excel("Udtræk fra TAO v2 til studenter.xlsx",\
                       usecols="A:B",\
                       names=["Dato", "Togpunktlighed"],\
                       sheet_name="Punktlighedstal for KH")
#inspiceres
df_kbh.head(5)
# Out:
#         Dato  Togpunktlighed
# 0 2015-01-01            83.3
# 1 2015-02-01            82.9
# 2 2015-03-01            87.0
# 3 2015-04-01            83.3
# 4 2015-05-01            78.1

# %% [markdown]
# ### Datamanipulering
# Punktligheden omskrives til procent. Årstal, kvartal og måned tilføjes.

# %%
# punktlighed omskrives til procent
df_kbh["Togpunktlighed"] = df_kbh["Togpunktlighed"]/100

# årstal tilføjes
df_kbh["Årstal"] = df_kbh["Dato"].dt.year

# kvartal tilføjes
def calc_quarter(date):
    return str(date.year) + " Q" + str(date.quarter)
df_kbh["Kvartal"] = df_kbh["Dato"].apply(calc_quarter)

# Måned tilføjes
def calc_month(date):
    month_list = ['Januar', 'Februar', 'Marts', 'April', 'Maj', 'Juni', 'Juli', 'August', 'September', 'Oktober',' November', 'December']
    n_month = date.month
    return month_list[n_month-1]
df_kbh["Måned"] = df_kbh["Dato"].apply(calc_month)

#inspiceres
df_kbh.head(13)
# Out:
#          Dato  Togpunktlighed  Årstal  Kvartal      Måned
# 0  2015-01-01           0.833    2015  2015 Q1     Januar
# 1  2015-02-01           0.829    2015  2015 Q1    Februar
# 2  2015-03-01           0.870    2015  2015 Q1      Marts
# 3  2015-04-01           0.833    2015  2015 Q2      April
# 4  2015-05-01           0.781    2015  2015 Q2        Maj
# 5  2015-06-01           0.771    2015  2015 Q2       Juni
# 6  2015-07-01           0.805    2015  2015 Q3       Juli
# 7  2015-08-01           0.781    2015  2015 Q3     August
# 8  2015-09-01           0.801    2015  2015 Q3  September
# 9  2015-10-01           0.800    2015  2015 Q4    Oktober
# 10 2015-11-01           0.740    2015  2015 Q4   November
# 11 2015-12-01           0.813    2015  2015 Q4   December
# 12 2016-01-01           0.797    2016  2016 Q1     Januar

# %% [markdown]
# #### Illustration
# Togpunktligheden på Københavns Hovedbanegård illustreres. Først per år, dernæst per kvartal.

# %%
split_vars = ['Årstal'] 
apply_vars = ['Togpunktlighed']
apply_fcts = ['mean']

df_illu = df_kbh.groupby(split_vars)[apply_vars].agg(apply_fcts)

x_labels = df_illu.index.get_level_values(0)
l_punkt = list(df_illu['Togpunktlighed']['mean'])

values = np.array(l_punkt)
x = range(len(values))

# plot
fig, ax = plt.subplots(figsize=(10,7))
rects = ax.bar(x, values, 0.6)

# labels på bar
for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           rotation=0, \
           fontsize='16', \
           horizontalalignment='center', \
           verticalalignment='top')
plt.tick_params(axis='x', direction='out', length=13, width=2)

# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# zoom ind
plt.ylim([0.65, 0.9])

# tilføj grid
plt.grid(axis = 'y')

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj titel
ax.set_title('Togpunktlighed på Københavns Hovedbanegård', \
             fontweight='bold', \
             fontsize='18')
# Out:
# Text(0.5, 1.0, 'Togpunktlighed på Københavns Hovedbanegård')

# %%
split_vars = ['Kvartal'] 
apply_vars = ['Togpunktlighed']
apply_fcts = ['mean']

df_illu = df_kbh.groupby(split_vars)[apply_vars].agg(apply_fcts)

x_labels = df_illu.index.get_level_values(0)
l_punkt = list(df_illu['Togpunktlighed']['mean'])

values = np.array(l_punkt)
x = range(len(values))

# plot
fig, ax = plt.subplots(figsize=(15,7))
rects = ax.bar(x, values, 0.6)#, color=['b', 'b', 'b', 'b', 'g', 'g', 'g', 'g'])

# labels på bar
for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           rotation=40, \
           fontsize='16', \
           horizontalalignment='right', \
           verticalalignment='top')
plt.tick_params(axis='x', direction='out', length=13, width=2)

# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# zoom ind
plt.ylim([0.65, 0.9])

# vertikale linjer mellem hvert år
ax.plot([3.5, 3.5], [0.65, 0.9], "k--")
ax.plot([7.5, 7.5], [0.65, 0.9], "k--")
ax.plot([11.5, 11.5], [0.65, 0.9], "k--")
ax.plot([15.5, 15.5], [0.65, 0.9], "k--")

# tilføj grid
plt.grid(axis = 'y')

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj titel
ax.set_title('Togpunktlighed på Københavns Hovedbanegård', \
             fontweight='bold', \
             fontsize='18')
# Out:
# Text(0.5, 1.0, 'Togpunktlighed på Københavns Hovedbanegård')

# %% [markdown]
# ## Sammenligning mellem Københavns Hovedbanegård og resten af DK
# Københavns Hovedbanegård med resten af landet i perioden 2016-2019. Først findes værdierne fra Københavns Hovedbanegård:

# %%
#år der skal sammenlignes
year_list = [2016, 2017, 2018, 2019]

split_vars = ['Årstal'] 
apply_vars = ['Togpunktlighed']
apply_fcts = ['mean']

df_illu = df_kbh[df_kbh["Årstal"].isin(year_list) == True].groupby(split_vars)[apply_vars].agg(apply_fcts)

l_kbh = list(df_illu['Togpunktlighed']['mean'])

# %% [markdown]
# Dernæst findes værdierne i årrækken for hele Danmark:

# %%
split_vars = ['Årstal'] 
apply_vars = ['Punktlighed']
apply_fcts = ['mean']

df_illu = df_punktlighed[df_punktlighed["Årstal"].isin(year_list) == True].groupby(split_vars)[apply_vars].agg(apply_fcts)

l_dk = list(df_illu['Punktlighed']['mean'])

# %% [markdown]
# Værdierne kan nu sammenlignes ved illustration:

# %%
x_labels = df_illu.index.get_level_values(0)
values1 = np.array(l_kbh)
values2 = np.array(l_dk)
x = np.arange(len(x_labels))

width = 0.35

# plot
fig, ax = plt.subplots(figsize=(10,7))
rects1 = ax.bar(x-width/2, values1, width, label='Københavns Hovedbanegård')
rects2 = ax.bar(x+width/2, values2, width, label='Hele Danmark')

# funktion der tilføjer procent over søjlerne
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.1%}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
        
# x-aksen
x_ticks = []
for i in range(len(x_labels)):
    x_ticks.append(i)
plt.xticks(x_ticks, x_labels, \
           fontsize='16', \
           horizontalalignment='center', \
           verticalalignment='top')
plt.tick_params(axis='x', direction='out', length=13, width=2)


# y-aksen
plt.yticks(
          fontsize='16', \
          horizontalalignment='right', \
          verticalalignment='center')
plt.tick_params(axis='y', direction='out', length=13, width=2)

# zoom ind
plt.ylim([0.65, 0.9])

# omdan y-aksen til procent
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))

# tilføj grid
plt.grid(axis = 'y')

# tilføj titel
ax.set_title('Togpunklighed: København H og resten af Danmark', \
             fontweight='bold', \
             fontsize='16')

# tilføj legend
plt.legend(loc="upper left", prop={'size': 16})

# %% [markdown]
# ## Passagertal
# Data på passagertal øst for Storebælt importeres:

# %%
#datasættet importeres fra excel fil
df_passager = pd.read_excel("Passagertal øst for storebælt 2006-2021.xlsx",\
                           usecols="C:BL",\
                           skiprows=[1,4,5,6])\
                           .T

#inspiceres
df_passager
# Out:
#                   0     1
# Unnamed: 2   2006K1  8598
# Unnamed: 3   2006K2  9143
# Unnamed: 4   2006K3  9194
# Unnamed: 5   2006K4  9465
# Unnamed: 6   2007K1  8946
# ...             ...   ...
# Unnamed: 59  2020K2  3760
# Unnamed: 60  2020K3  6396
# Unnamed: 61  2020K4  5369
# Unnamed: 62  2021K1  3260
# Unnamed: 63  2021K2  5611
#
# [62 rows x 2 columns]
